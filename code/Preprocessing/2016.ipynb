# %%
import pandas as pd

# File path of the Excel file
file_path = r"..\..\data\Raw_data\2016 Ele Deaths.xlsx"
rows_to_skip = [0,1,2, 28,54,76,98,120,142,170,200,225,256,275]
# Read the Excel file into a pandas DataFrame
df = pd.read_excel(file_path,skiprows=rows_to_skip)

# %%
df.head()
# Out:
#    අනු අංකය       කලාපය දිස්ත්‍රික්කය ප්‍රා.ලේ.කො. පොලීසිය මියගිය දිනය  \
# 0         1    වවුනියාව      වවුනියාව        වවුනියාව දෙමල  2016-01-11
# 1         2          ඌව       මොනරාගල               බුත්තල  2016-01-09
# 2         3  පොලොන්නරුව    පොලොන්නරුව            දිඹුලාගල   2016-01-18
# 3         4  පොලොන්නරුව    පොලොන්නරුව           හිඟුරක්ගොඩ  2016-01-25
# 4         5  පොලොන්නරුව    පොලොන්නරුව             වැලිකන්ද  2016-01-30
#
#                මියගිය ස්ථානය./         ග්‍රා.නි. වසම            මියයෑමට හේතුව  \
# 0                ඉරනතිරිප්පුකුලම කෝවිල් පුලියන්කුලම්       විදුලිසැර වැදීමෙන්
# 1                කසල ප්‍රතිචක්‍රිකරණ මධ්‍යස්ථානය අසල             වෙඩිවැදීමෙන්
# 2  වීරලන්ද කුඩා සීගිරිය වලස්ගල රක්ෂිතය තුළ  පිඹුර...            හඳුනාගත නොහැක
# 3                        ගිරිතලේ පශු වෛද්‍ය ඒකකය තුළ  ප්‍රතිශක්තිය දුර්වල වීම
# 4                                         මඟුල්පොකුණ       විදුලිසැර වැදීමෙන්
#
#   ස්ත්‍රි/පුරුෂ භාවය වයස අවු:
# 0             පිරිමි    25 -30
# ...

# %%
def replace_column_names_with_english(column_name):
    translations = {
        'අනු අංකය': 'No',
        'කලාපය': 'Region',
        'දිස්ත්‍රික්කය': 'District',
        'ප්‍රා.ලේ.කො. පොලීසිය': 'D/S Office',
        'මියගිය දිනය': 'Date of Death',
        'මියයෑමට හේතුව': 'Cause of Death',
        'ස්ත්‍රි/පුරුෂ භාවය': 'Sex',
        'වයස අවු: ': 'Age',
        'ප.ම.ප. කර ඇති බව': 'Reported to Police',
        '    මියගිය ස්ථානය./         ග්‍රා.නි. වසම': 'Place of Death'
    }
    return translations.get(column_name, column_name)
df.rename(columns=replace_column_names_with_english, inplace=True)

# %%
df.columns
# Out:
# Index(['No', 'Region', 'District', 'D/S Office', 'Date of Death',
#        'Place of Death', 'Cause of Death', 'Sex', 'Age'],
#       dtype='object')

# %%
df = df.drop(columns=['Place of Death'])

# %%
df["Region"].unique()
# Out:
# array(['වවුනියාව', 'ඌව', 'පොලොන්නරුව', 'මධ්\u200dයම', 'පුත්තලම',
#        'නැඟෙනහිර', 'ත්\u200dරිකුණාමලය', 'වයඹ', 'දකුණ', 'ETH',
#        'අනුරාධපුරය', 'වව්නියාව', 'නැගෙනහිර', 'කිලිනොච්චිය', 'පොළොන්නරුව'],
#       dtype=object)

# %%
df['Region'] = df['Region'].replace({
        'පොලොන්නරුව': 'Polonnaruwa',
        'නැඟෙනහිර': 'Eastern',
        'ඌව': 'Uva',
        'අනුරාධපුරය': 'Anuradhapura',
        'වයඔ': 'Wayamba',
        'ඇත්අතුරු සෙවන': 'Elephant Transit Home',
        'වවුනියාව': 'Vavuniya',
        'පුත්තලම': 'Puttalam',
        'දකුණ': 'Southern',
        'ත්\u200dරිකුණාමලය': 'Trincomalee',
        'වයඹ': 'Wayamba',
        'මධ්\u200dයම ': 'Central',
        'මධ්‍යම': 'Central',
        'කිලිනොච්චිය': 'Kilinochchi',
        'අනුරාධපුර': 'Anuradhapura',
        'ඌව ': 'Uva',
        'අනුරාපුරය': 'Anuradhapura',
        'පොළොන්නරුව':'Polonnaruwa',
        'නැගෙනහිර':'Eastern',
        'වව්නියාව':'Vavuniya'

})

# %%
df["Region"].unique()
# Out:
# array(['Vavuniya', 'Uva', 'Polonnaruwa', 'Central', 'Puttalam', 'Eastern',
#        'Trincomalee', 'Wayamba', 'Southern', 'ETH', 'Anuradhapura',
#        'Kilinochchi'], dtype=object)

# %%
df[df['Region'] == 'ETH']
# Out:
#       No Region District D/S Office Date of Death Cause of Death     Sex  Age
# 23    26    ETH      NaN        NaN           NaN       ස්වභාවික  පිරිමි  NaN
# 129  132    ETH      NaN        NaN           NaN       ස්වභාවික  පිරිමි  NaN
# 130  133    ETH      NaN        NaN           NaN       ස්යභාව්ක  ගැහැණු  NaN
# 240  243    ETH      NaN        NaN           NaN       ස්වභාවික     NaN  NaN
# 241  244    ETH      NaN        NaN           NaN       ස්වභාවික     NaN  NaN
# 242  245    ETH      NaN        NaN           NaN       ස්වභාවික     NaN  NaN
# 260  263    ETH      NaN        NaN           NaN       ස්වභාවික     NaN  NaN
# 271  274    ETH      NaN        NaN           NaN       ස්වභාවික     NaN  NaN

# %%
df = df[~(df['Region'] == 'ETH')]

# %%
df['District'].unique()
# Out:
# array(['වවුනියාව', 'මොනරාගල', 'පොලොන්නරුව', 'බදුල්ල', 'පුත්තලම',
#        'මඩකලපුව', 'අම්පාර', 'ත්\u200dරිකුණාමලය', 'කුරුණෑගල', 'අනුරාධපුරය',
#        'මන්නාරම', 'මහනුවර', 'මාතලේ', 'රත්නපුර', 'මුලතිව්', 'හම්බන්තොට',
#        'මොණරාගල', 'කිලිනොච්චිය', 'රත්නපුරය', 'පුත්තලම ', 'පොළොන්නරුව'],
#       dtype=object)

# %%
df['District'] = df['District'].replace({
       'පොලොන්නරුව': 'Polonnaruwa',
        'නැඟෙනහිර': 'Eastern',
        'ඌව': 'Uva',
        'අනුරාධපුරය': 'Anuradhapura',
        'වයඔ': 'Wayamba',
        'ඇත්අතුරු සෙවන': 'Elephant Transit Home',
        'වවුනියාව': 'Vavuniya',
        'පුත්තලම': 'Puttalam',
        'දකුණ': 'Southern',
        'ත්‍රිකුණාමලය': 'Trincomalee',
        'වයඹ': 'Wayamba',
        'මධ්‍යම ': 'Central',
        'කිලිනොච්චිය': 'Kilinochchi',
        'අනුරාධපුර': 'Anuradhapura',
        'ඌව ': 'Uva',
        'අනුරාපුරය': 'Anuradhapura',
        'මඩකලපුව': 'Batticaloa',
        'මොනරාගල': 'Monaragala',
        'අම්පාර': 'Ampara',
        'කුරුණෑගල': 'Kurunegala',
        ' -  ': '-',
        'හම්බන්තොට': 'Hambantota',
        'මන්නාරම': 'Mannar',
        'ත්\u200dරිකුණාමලය': 'Trincomalee',
        'බදුල්ල': 'Badulla',
        'මුලතිව්': 'Mullaitivu',
        'මාතලේ': 'Matale',
        'රත්නපුරය': 'Ratnapura',
        'අනුරාධුරය': 'Anuradhapura',
        'කිලිනොච්චිය': 'Kilinochchi',
        'මහනුවර':'Kandy',
        'මොණරාගල':'Monaragala',
        'රත්නපුර':'Ratnapura',
        'පුත්තලම ':'Puttalam',
        'පොළොන්නරුව':'Polonnaruwa'

})

# %%
df['District'].unique()
# Out:
# array(['Vavuniya', 'Monaragala', 'Polonnaruwa', 'Badulla', 'Puttalam',
#        'Batticaloa', 'Ampara', 'Trincomalee', 'Kurunegala',
#        'Anuradhapura', 'Mannar', 'Kandy', 'Matale', 'Ratnapura',
#        'Mullaitivu', 'Hambantota', 'Kilinochchi'], dtype=object)

# %%
df['D/S Office'].unique()
# Out:
# array(['වවුනියාව දෙමල', 'බුත්තල', 'දිඹුලාගල ', 'හිඟුරක්ගොඩ', 'වැලිකන්ද',
#        'මහියංගණය', 'පුත්තලම', 'වවුනතිව්', 'කිරාන්', 'පට්ටිපලෙයි',
#        'වව්නතිවු', 'තිරික්කෝවිල්', 'පොතුවිල්', 'ආලයඩිවෙම්බු', 'කුච්චවේලි',
#        'මහව', 'තණමල්විල', 'ගල්ගමුව', 'ගිරිබාව', 'සේරුනුවර', 'කන්තලේ',
#        'හොරොව්පොතාන', 'සිලාවතුර', 'පදවිය ', 'මිණිපේ', 'දඹුල්ල',
#        'තමන්කඩුව', 'මැදිරිගිරිය', 'පට්ටිපොල', 'මහඔය', 'වාකරේ', 'චෙංකලඩි',
#        'කරුවලගස්වැව', 'වවුනියාව උතුව', 'ඇලහැර', 'මොනරාගල', 'වැල්ලවාය',
#        'සම්මන්තුරේ', 'කැබිතිගොල්ලෑව', 'නොච්චියාගම', 'පලුගස්වැව',
#        'වෙරුගල්', 'මොරවැව', 'ගෝමරන්කඩවල', 'පොල්පිතිගම', 'ඇහැටුවැව',
#        'බලංගොඩ', 'නාවුල', 'දිඹුලාගල', 'හිගුරක්ගොඩ', 'හල්දුම්මුල්ල',
#        'ම.නු.ප.', 'මඩු', 'කොටවෙහෙර', 'ඔඩ්ඩුසුඩාන්', 'හම්බන්තොට', 'මූසලී',
#        'මහවිලච්චිය', 'අම්පාර', 'ලාහුගල', 'දෙහිඅත්තකණ්ඩිය', 'අඹන්පොල',
#        'මුලන්කාවිල්', 'මහඹය', 'දමන', 'උහන', 'කහටගස්දිගිලිය', 'තලාව',
# ...

# %%
df['D/S Office'] = df['D/S Office'].replace({
        'දිඹුලාගල':'Dimbulagala',
        'දිඹුලාගල ':'Dimbulagala',
        'අඩ්ඩාලච්චේන':'Addalachchena',
        'වැලිකන්ද':'Welikanda',
        'බිබිල':'Bibila',
        'තිරුක්කෝවිල්':'Thirikkovil',
        'වාකරේ':'Wakare',
        'හොරොව්පොතාන':'Horowpathana',
        'පළුගස්වැව':'Palugaswewa',
        'මහඔය':'Mahaoya',
        'මහඹය':'Mahaoya',
        'ඹහඔය':'Mahaoya',
        'නොච්චියාගම':'Nochchiyagama',
        'පොතුවිල්':'Pothuwil',
        'අලිඅඩිවෙම්බු':'Alayadivembu',
        'ආලයඩිවෙම්බු':'Alayadivembu',
        'පොල්පිතිගම':'Polpithigama',
        ' -  ':' - ',
        'මන්මුරේ නිරිත(පට්ටිපොල)':'Pattipola',
        'මැදවච්චිය':'Madavachchiya',
        'තිස්සමහාරාමය':'Thissamaharamaya',
        'කහටගස්දිගිලිය':'Kahatagasdigiliya',
        'නෙදුන්කර්නි':'Nedunkanar',
        'අඩම්පන්':'Adampan',
        'වනාතවිල්ලුව':'Wanathawilluwa',
        'වැල්ලවාය':'Wellawaya',
        'හම්බන්තොට':'Hambantota',
        'කැබිතිගොල්ලෑව':'Kabithigollawa',
        'කිරාන්':'Kiran',
        'ගෝමරන්කඩවල':'Gomarankadawala',
        'පලුගස්වැව':'Palugaswewa',
        'තණමල්විල':'Thanamalwila',
        'චෙන්කල්අඩි':'Chenkaladi',
        'තලාව':'Thalawa',
        'දමන':'Damana',
        'තිරික්කෝවිල්': 'Thirikkovil',
        'තමන්කඩුව': 'Tamankaduwa',
        'නැදුන්කර්නි': 'Nadunkanari',
        'අඹන්පොල': 'Ambanpola',
        'විලච්චිය': 'Vilachchiya',
        'සියඹලාණ්ඩුව': 'Siyabalanduwa',
        'සියඔලාණ්ඩුව':'Siyabalanduwa',
        'සම්මන්තුරේ': 'Samanthurai',
        'මහියංගණය': 'Mahiyangana',
        'නවගත්තේගම': 'Navagattegama',
        'වැලිඔය': 'Welioya',
        'තිරප්පනේ': 'Tirappane',
        'පුත්තලම දකුණ': 'Puttalam',
        'කන්තලේ': 'Kanthale',
        'ගල්ගමුව': 'Galgamuwa',
        'හල්දුම්මුල්ල': 'Haldhummulla',
        'කන්දකැටිය': 'Kandakatiya',
        'වවුනියාව': 'vavuniya',
        'වවුනියාව දෙමල':'vavuniya',
        'මුතූර්':'Mutur',
        'පුත්තලම': 'Puttalam',
        'සේරුවිල': 'Seruvila',
        'මඩුල්ල': 'Madulla',
        'කැකිරාව': 'Kakirawa',
        'නාඋල': 'Naula',
        'ම. නු. ප.': 'M.N.P',
        'ම.නු.ප.':'M.N.P',
        'හිඟුරක්ගොඩ': 'Hingurakgoda',
        'විල්ගමුව': 'Vilgamuwa',
        'ලාහුගල': 'Lahugala',
        'කුච්චවේලි': 'Kuchchaveli',
        'මැදිරිගිරිය': 'Madirigiriya',
        'මොරවැව': 'Morawewa',
        'මඩු': 'Madu',
        'මොනරාගල': 'Monaragala',
        'දඹුල්ල': 'Dambulla',
        'කොටවෙහෙර': 'Kotavehera',
        'කරුවලගස්වැව': 'Karuwalgaswewa',
        'බලංගොඩ': 'Balangoda',
        'දෙහිඅත්තකණ්ඩිය': 'Dehiaththakandiya',
        'මහකුඹුක්කඩවල': 'Mahakubukkadawala',
        'සෙට්ටිකුලම': 'Settikulama',
        'සෙට්ට්කුලම':'Settikulama',
        'සිරිපුර': 'Siripura',
        'චෙංකලඩි': 'Chankaladi',
        'සමන්තුරේ': 'Samanthurai',
        'පලාගල': 'Palagala',
        'ඇලහැර': 'Alahara',
        'කතරගම': 'Kataragama',
        'සුරියවැව': 'Suriyawewa',
        'සූරියවැව':'Suriyawewa',
        'ගිරිබාව': 'Giribawa',
        'බුත්තල': 'Buttala',
        'ඇඹිලිපිටිය': 'Ambilipitiya',
        'අැඹිලිපිටිය':'Ambilipitiya',
        'සේරුනුවර': 'Serunuwara',
        'මුසලි': 'Musali',
        'මූසලී':'Musali',
        'ඇහැටුවැව': 'Ahatuwewa',
        'නගර හා කඩවත්': 'Nagara Ha Kadavatha',
        'මාන්කුලම': 'Mankulama',
        'මහවිලච්චිය': 'Mahawilachchiya',
        'මහව': 'Mahawa',
        'තිරප්පනය': 'Tirappane',
        'චෙංකල්ලඩි': 'Chenkaladi',
        'ගලෙන්බිදුණුවැව': 'Galenbindunuwewa',
        'රඹෑව': 'Rambawa',
        'වැලිගෙපොල': 'Weligepola',
        'වවුනතිව්':'Wawunathiw',
        'වව්නතිවු':'Wawunathiw',
        'සිලාවතුර':'Silawathura',
        'පදවිය ':'Padaviya',
        'මිණිපේ':'Minipe',
        'පට්ටිපොල':'Pattipola',
        'වවුනියාව උතුව':'vavuniya',
        'වෙරුගල්':'Werugal',
        'නාවුල':'Naula',
        'හිගුරක්ගොඩ':'Hingurakgoda',
        'ඔඩ්ඩුසුඩාන්':'Oddusuddan',
        'අම්පාර':'Ampara',
        'මුලන්කාවිල්':'Mulankavil',
        'සෙවනගල':'Sevanagala',
        'තඹලගමුව':'Thambalagamuwa',
        'උඩදුම්බර':'Udadumbara',
        'මාන්තෙයි බටහිර':'Manthai west',
        'නින්දවුර්':'Nintavur',
        'ලංකාපුර':'Lankapura',
        'නානාටන්':'nanattan',
        'ගල්කිරියාගම':'Galkiriyagama',
        'පට්ටිපලෙයි':'Pattipalei',
        'උහන':'Uhana'

})

# %%
df['D/S Office'].unique()
# Out:
# array(['vavuniya', 'Buttala', 'Dimbulagala', 'Hingurakgoda', 'Welikanda',
#        'Mahiyangana', 'Puttalam', 'Wawunathiw', 'Kiran', 'Pattipalei',
#        'Thirikkovil', 'Pothuwil', 'Alayadivembu', 'Kuchchaveli', 'Mahawa',
#        'Thanamalwila', 'Galgamuwa', 'Giribawa', 'Serunuwara', 'Kanthale',
#        'Horowpathana', 'Silawathura', 'Padaviya', 'Minipe', 'Dambulla',
#        'Tamankaduwa', 'Madirigiriya', 'Pattipola', 'Mahaoya', 'Wakare',
#        'Chankaladi', 'Karuwalgaswewa', 'Alahara', 'Monaragala',
#        'Wellawaya', 'Samanthurai', 'Kabithigollawa', 'Nochchiyagama',
#        'Palugaswewa', 'Werugal', 'Morawewa', 'Gomarankadawala',
#        'Polpithigama', 'Ahatuwewa', 'Balangoda', 'Naula', 'Haldhummulla',
#        'M.N.P', 'Madu', 'Kotavehera', 'Oddusuddan', 'Hambantota',
#        'Musali', 'Mahawilachchiya', 'Ampara', 'Lahugala',
#        'Dehiaththakandiya', 'Ambanpola', 'Mulankavil', 'Damana', 'Uhana',
# ...

# %%
df['Date of Death'].unique()
# Out:
# array(['2016-01-11', '2016-01-09', '2016-01-18', '2016-01-25',
#        '2016-01-30', '2016-01-10', '2016-01-07', '2016-01-08',
#        '2016-01-13', '2016-01-19', '2016-01-20', '2016-01-03',
#        '2016-01-06', '2016-01-14', '2016-01-29', '2016-01-15',
#        '2016-02-01', '2016-02-18', '2016-02-25', '2016-2-05',
#        '2016-02-03', '2016-02-06', '2016-02-13', '2016-02-04',
#        '2016-02-26', '2016-02-10', '2016-02-23', '2016-02-16',
#        '2016-02-29', '2016-02-02', '2016-02-08', '2016-02-20',
#        '2016-03-02', '2016-03-14', '2016-03-01', '2016-03-03',
#        '2016-03-09', '2016-03-23', '2016-03-05', '2016-03-22',
#        '2016-03-08', '2016-03-10', '2016-03-25', '2013-03-13',
#        '2016-03-24', '2016-03-26', '2016-03-04', '2016-03-20',
#        '2016-04-11', '2016-04-05', '2016.04.22', '2016-04-25',
#        '2016.04.18', '2016.04.11', '2016.04.27', '2016.04.26',
#        '2016-04-07', '2016-04-03', '2016-04-26', '2016.04.30',
# ...

# %%
df['Date of Death'] = df['Date of Death'].replace({
    '03.25 පසුව දැනගන්නා ලදී':'2016-03-25',
    '2016-10':'2016-08-31',
    '2016-2-05':'2016-02-05',
    '2013-03-13':'2016-03-13',
    '2015.05.05':'2016-05-05'

})

# %%
df[df['Date of Death'].isnull()]
# Out:
# Empty DataFrame
# Columns: [No, Region, District, D/S Office, Date of Death, Cause of Death, Sex, Age]
# Index: []

# %%
df['Date of Death'].unique()
# Out:
# array(['2016-01-11', '2016-01-09', '2016-01-18', '2016-01-25',
#        '2016-01-30', '2016-01-10', '2016-01-07', '2016-01-08',
#        '2016-01-13', '2016-01-19', '2016-01-20', '2016-01-03',
#        '2016-01-06', '2016-01-14', '2016-01-29', '2016-01-15',
#        '2016-02-01', '2016-02-18', '2016-02-25', '2016-02-05',
#        '2016-02-03', '2016-02-06', '2016-02-13', '2016-02-04',
#        '2016-02-26', '2016-02-10', '2016-02-23', '2016-02-16',
#        '2016-02-29', '2016-02-02', '2016-02-08', '2016-02-20',
#        '2016-03-02', '2016-03-14', '2016-03-01', '2016-03-03',
#        '2016-03-09', '2016-03-23', '2016-03-05', '2016-03-22',
#        '2016-03-08', '2016-03-10', '2016-03-25', '2016-03-13',
#        '2016-03-24', '2016-03-26', '2016-03-04', '2016-03-20',
#        '2016-04-11', '2016-04-05', '2016.04.22', '2016-04-25',
#        '2016.04.18', '2016.04.11', '2016.04.27', '2016.04.26',
#        '2016-04-07', '2016-04-03', '2016-04-26', '2016.04.30',
# ...

# %%
# Replace periods with hyphens in the 'Date of Death' column
df['Date of Death'] = df['Date of Death'].str.replace('.', '-')

# Convert the date column to pandas datetime format
df['Date of Death'] = pd.to_datetime(df['Date of Death'], format='%Y-%m-%d')

# %%
df['Date of Death'].unique()
# Out:
# <DatetimeArray>
# ['2016-01-11 00:00:00', '2016-01-09 00:00:00', '2016-01-18 00:00:00',
#  '2016-01-25 00:00:00', '2016-01-30 00:00:00', '2016-01-10 00:00:00',
#  '2016-01-07 00:00:00', '2016-01-08 00:00:00', '2016-01-13 00:00:00',
#  '2016-01-19 00:00:00',
#  ...
#  '2016-12-25 00:00:00', '2016-12-12 00:00:00', '2016-12-13 00:00:00',
#  '2016-12-15 00:00:00', '2016-12-31 00:00:00', '2016-12-29 00:00:00',
#  '2016-12-21 00:00:00', '2016-12-07 00:00:00', '2016-12-24 00:00:00',
#  '2016-12-30 00:00:00']
# Length: 186, dtype: datetime64[ns]

# %%
df = df.sort_values(by='Date of Death').reset_index(drop=True)

# %%
df['No'] = df.index + 1

# %%
df
# Out:
#       No        Region      District      D/S Office Date of Death  \
# 0      1       Eastern        Ampara     Thirikkovil    2016-01-03
# 1      2       Eastern        Ampara        Pothuwil    2016-01-06
# 2      3       Eastern    Batticaloa      Wawunathiw    2016-01-07
# 3      4       Eastern    Batticaloa           Kiran    2016-01-08
# 4      5           Uva    Monaragala         Buttala    2016-01-09
# ..   ...           ...           ...             ...           ...
# 264  265       Wayamba  Anuradhapura   Galkiriyagama    2016-12-25
# 265  266      Puttalam      Puttalam  Karuwalgaswewa    2016-12-25
# 266  267       Eastern    Batticaloa           Kiran    2016-12-29
# 267  268  Anuradhapura  Anuradhapura    Horowpathana    2016-12-30
# 268  269       Wayamba  Anuradhapura   Galkiriyagama    2016-12-31
#
#                           Cause of Death     Sex          Age
# 0                         සඳහන් කර නොමැත  පිරිමි        20-25
# ...

# %%
df['Cause of Death'].unique()
# Out:
# array(['සඳහන් කර නොමැත', 'විදුලිසැර වැදීමෙන්', 'වෙඩිවැදීමෙන්',
#        'අතේ ඇතිවු තුවාලයක්', 'වෙඩිවැදිමෙන්', 'හක්කපටස්', 'හඳුනාගත නොහැක',
#        'ප්\u200dරතිශක්තිය දුර්වල වීම', 'සිරුර ජීර්ණය වි ඇත',
#        'වෙඩිවැදීමක් හෝ තුවාල අසාදනයක්', 'විෂ ශරීර ගතවීමෙන්',
#        'බසයක හැපීමෙන්', 'ඇතෙකු සමඟ ගැටුමකින්', 'මද්දකට හසුවීමෙන් ',
#        'නිගමනය කළනොහැක', 'කම්පනය හේතුවෙන්', 'ස්වභාවික', 'සෙප්ටසීමියා',
#        'බිම්බෝම්බයකට  හසුවී  හා වලකට වැටීම', 'දුම්රියේ හැපීමෙන්',
#        'දකුණු පාදයේ විශාල ගෙඩියක් පිපිරි යාම', 'වෙඩිතැබීමකින්',
#        'හිස්කබලට හා මොලයට හනි සිදුවිම', nan,
#        'කකුලේ ඇති වූ තුවාලයක් හේතුවෙන්', 'වාර්තාව ලැබී නොමැත',
#        'අභ්\u200dයන්තර රුදිර වහනය', 'ඔය ඉවුරේ වැටී සුසුම්නාව කැඩීමෙන්',
#        'විදුලි සැර වැදීම', 'හක්කපටස් ', 'වාහනයක ගැටීමෙන්',
#        'අකුණු සැර වැදීම', 'කම්බිමල පුඩුවක් ගෙල සිරවීමෙන්',
#        'පාදයේ තුවාලය හේතුවෙන්', 'නොදනි', 'වෙඩි වැදීම',
#        'නරක් වී තිබීම නිසා නිගමනය කල නොහැක.', 'රිය අනතුරකින්',
# ...

# %%
def replace_sinhala_with_english(text):
    translations = {
    'විදුලිසැර වැදීමෙන්': 'Electrocuted',
    'වෙඩිවැදීමෙන්': 'Gunshot',
    'හඳුනාගත නොහැක': 'Unknown',
    'ප්\u200dරතිශක්තිය දුර්වල වීම': 'Other',
    'අතේ ඇතිවු තුවාලයක්': 'Injured',
    'හක්කපටස්': 'Hakkapatas',
    'සඳහන් කර නොමැත': 'Unknown',
    'වෙඩිවැදිමෙන්': 'Gunshot',
    'ස්වභාවික': 'Natural',
    'විෂ ශරීර ගතවීමෙන්': 'Poisned',
    'සිරුර ජීර්ණය වි ඇත': 'Body destroyed',
    'වෙඩිවැදීමක් හෝ තුවාල අසාදනයක්': 'Gunshot',
    'බසයක හැපීමෙන්': 'Accident',
    'නිගමනය කළනොහැක': 'Unknown',
    'බිම්බෝම්බයකට  හසුවී  හා වලකට වැටීම': 'Land mine',
    'මද්දකට හසුවීමෙන් ': 'Other',
    'කම්පනය හේතුවෙන්': 'Other',
    'දුම්රියේ හැපීමෙන්': 'Train Accident',
    'ඇතෙකු සමඟ ගැටුමකින්': 'Attack by an elephant',
    'සෙප්ටසීමියා': 'Septicemia',
    'දකුණු පාදයේ විශාල ගෙඩියක් පිපිරි යාම': 'Injured',
    'ඔය ඉවුරේ වැටී සුසුම්නාව කැඩීමෙන්': 'Broken the Spinal',
    'කකුලේ ඇති වූ තුවාලයක් හේතුවෙන්': 'Injured',
    'වෙඩිතැබීමකින්': 'Gunshot',
    'හිස්කබලට හා මොලයට හනි සිදුවිම': 'Injured',
    'හක්කපටස් ': 'Hakkapatas',
    'වාහනයක ගැටීමෙන්': 'Accident',
    'අභ්\u200dයන්තර රුදිර වහනය': 'Injured',
    'විදුලි සැර වැදීම': 'Electrocuted',
    'වාර්තාව ලැබී නොමැත': 'Unknown',
    'දකුණු අතට වෙඩි වැදී තුවාලය අසාදනය වීමෙන්': 'Gunshot',
    'රිය අනතුරකින්': 'Accident',
    'වෙඩි වැදීම': 'Gunshot',
    'කම්බිමල පුඩුවක් ගෙල සිරවීමෙන්': 'Other',
    'අකුණු සැර වැදීම': 'Lightning',
    'පාදයේ තුවාලය හේතුවෙන්': 'Injured',
    'නොදනි': 'Unknown',
    'විදුලිසැර වද්දවා': 'Electrocuted',
    'වෙඩි තබා': 'Gunshot',
    'දක්වා නැත': 'Unknown',
    'දියේ ගිලීමෙන්': 'Drowned',
    'පාචන රෝගය සෑදීම නිසා': 'Disease',
    ' - ': 'Unknown',
    'වෙඩි වැදීමෙන්': 'Gunshot',
    'නරක් වී තිබීම නිසා නිගමනය කල නොහැක.': 'Body destroyed',
    'ස්යභාව්ක': 'Natural',
    'දුම්රියේ ගැටීමෙන්': 'Train Accident',
    'ශ්වසන නාල අවහිර වීමෙන්': 'Other',
    'වෙඩිතබා මරණයට පත් කිරීමෙන්': 'Gunshot',
    'දිවෙහි තිබු තුවාලයක් නිසා ආහාර ගැනීමට නොහැකිව': 'Injured',
    'ශරීරයේ අභ්\u200dයන්තර පරතෝෂතාවය නිසා': 'Disease',
    'ශරීරය දිරාපත්වී ඇති බැවින් හදුනාගත නොහැක': 'Body destroyed',
    'සෙප්ටමීනියා': 'Septicemia',
    'තුවාලයක් ආසාදනය වීම': 'Injured',
    'මුඛයට හානි සිදුවීමෙන්': 'Injured',
    'මලසිරුර කුණුවී ඇති බැවින් හේතුව නිශ්චිතව සඳහන් කල නොහැක.': 'Body destroyed',
    'වළකට වැටීමෙන්': 'Fallen into well',
    'ළිඳකට වැටීමෙන්': 'Fallen into well',
    'අලිගැටුමකින්': 'Attack by an elephant',
    'වෙඩිප්\u200dරහාරයකින්': 'Gunshot',
    'රුහුණුදුම්රියට වැදීමෙන්': 'Train Accident',
    'මුඛයේ හටගත් තුවාලයක් නිසා නිරාහාරව සිටීම': 'Injured',
    'රෝගී තත්වයක් නිසා': 'Disease',
    'උදර ප්\u200dරදේශයේ ගෙඩියක්': 'Injured',
    'පණු හානි අක්මාව': 'Disease',
    'PM වාර්තාව ලැබීනැත': 'Unknown',
    'පණු රෝගය හෝ මඩේ එරීම': 'Disease',
    'පණුරෝගයක්': 'Disease',
    'අසනීපතත්වයන් විමා': 'Disease',
    'වෙඩිවැදීමකින්': 'Gunshot',
    'අසනීප තත්වයක් විම': 'Disease',
    'ගලකෙමකට හසුවීමෙන්': 'Other',
    'සනාථකර ගත නොහැක': 'Unknown',
    'ශරිර අභ්\u200dයන්තරයේ  රෝගයක් විම': 'Disease',
    'හේතුව සඳහන් කරනැත': 'Unknown',
    'මෙතෙක් සිදුකරනැත': 'Unknown',
    'පොලිතින් ආහාරයට ගැනීම': 'Eaten polythene',
    'වැසිකිළි වලකට වැටී සිරවීමෙන්': 'Fallen into well',
    'වස ශරීරගත වීමෙන්': 'Poisned',
    'ආහාරගැනීමේ අපහසුව': 'Other',
    'පොලිතින් බඩවැලේ සිරවීමෙන්': 'Eaten polythene',
    'හිසේ හා ඉල ප්\u200dරදේශයේ සිදුවු තුවාල': 'Injured',
    'ස්වභාවික මරණයක්': 'Natural',
    'අභ්\u200dයන්තර රුධිර වහනය': 'Other',
    'විෂ බීජයක් ඇතුළත්වීමෙන්': 'Poisned',
    'පරපෝෂිත අසාධනයක්': 'Disease',
    'පණු රෝගයක් නිසා': 'Disease',
    'වයස්ගතවීම, පණුරෝගය': 'Disease',
    'සිලින්ඩර් යෙදූ ළිඳකට වැටී සිරවීමෙන්': 'Fallen into well',
    'විදුලි සැර වැදීමෙන්': 'Electrocuted',
    'බදින තුවක්කුවක් පත්තු වීමෙන්': 'Gunshot',
    'හදුනාගත නොහැක': 'Unknown'
    }
    return translations.get(text, text)

# %%
df["Cause of Death"] = df["Cause of Death"].apply(replace_sinhala_with_english)

# %%
df['Cause of Death'] = df['Cause of Death'].fillna('Unknown')

# %%
df['Cause of Death'].unique()
# Out:
# array(['Unknown', 'Electrocuted', 'Gunshot', 'Injured', 'Hakkapatas',
#        'Other', 'Body destroyed', 'Poisned', 'Accident',
#        'Attack by an elephant', 'Natural', 'Septicemia', 'Land mine',
#        'Train Accident', 'Broken the Spinal', 'Lightning', 'Disease',
#        'Drowned', 'Fallen into well', 'Eaten polythene'], dtype=object)

# %%
df['Sex'].unique()
# Out:
# array(['පිරිමි', 'ගැහැණු', 'හඳුනාගත නොහැක', 'ඇතෙක්', 'පිරිමි ඇතෙකි',
#        'ගැහුණු', 'පිරිමි ', 'මාස 2 කට පෙර', '-', 'ගැහැණුු',
#        'පිරිමිඇත්පැටවා', nan, 'නොදනී'], dtype=object)

# %%
df['Sex'] = df['Sex'].replace({
    'පිරිමි': 'Male',
    'ඇතෙක්': 'Male',
    'ගැහැණු': 'Female',
    'හඳුනාගත නොහැක': 'Unknown',
    'ගැහුණු': 'Female',
    'පිරිමි ඇතෙකි': 'Male',
    'මාස 2 කට පෙර': 'Unknown',
    'පිරිමි ': 'Male',
    'ගැහැණුු': 'Female',
    '-': 'Unknown',
    'පිරිමිඇත්පැටවා': 'Male',
    'නොදනී': 'Unknown'
})

# %%
df['Sex'] = df['Sex'].fillna('Unknown')

# %%
df['Sex'].unique()
# Out:
# array(['Male', 'Female', 'Unknown'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array(['20-25', '30-35', '25', '10-15', 35, '25 -30', 15, '7', '8',
#        '15-20', 30, '35-40', '40-45', '30', 33, '5-7', 'සති 7-8', '08-10',
#        '25-30', '10-12', '55-60', '5-6', '12-15', '18-20', 'මාස 05-06',
#        '6-8', '12', '15', '20', '28-30', '8-25', 'මාස 03-05', '1', '8-9',
#        '45', '6', '9-10', '20-30', 'මාස 10', '03', '4-5', '8-10', '16',
#        'මාස 10-12', 'මාස 8', '2-3', '05', '10', 'මාස 02', 'මාස 5', nan,
#        'අවු:2,1/2', '30 - 35', '08 - 10', 'මාස 01', '15 - 20', '20 - 22',
#        '35', '45 - 50', 'හඳුනාගත නොහැක', '07', 'මාස 04', '40 - 45',
#        'අවු: 18', 'මාස 06', '25 - 30', 'අවු: 15-18', '20 - 25', '5 - 6',
#        'අවු: 30', 'මාස 06 - 07', 'මාස 2', '4', '3-4', '6-7', 4, '15-18',
#        '4-6', '5', '1,1/2-2', '22', '50', 'අවු: 15', 'අවු: 6-10',
#        'අවු:2-3', 'අවු: 15-20', 'අවු: 5', 'අවු: 1,1/2', 'අවු:30',
#        'අවු:10-15', 'අවු: 08', 'අවු: 35', 'මාස 2 ක් පමණ', 'අවු: 3',
# ...

# %%
# Step 1: Convert the 'Age' column to string type
df['Age'] = df['Age'].astype(str)

# Step 2: Remove the word 'අවු:' and replace 'හඳුනාගත නොහැක' with 'Unknown'
df['Age'] = df['Age'].str.replace('අවු: ', '')
df['Age'] = df['Age'].str.replace('හඳුනාගත නොහැක', 'Unknown')
df['Age'] = df['Age'].str.replace('අවු : ','')
df['Age'] = df['Age'].str.replace('අවු:', '')

# %%
df['Age'].unique()
# Out:
# array(['20-25', '30-35', '25', '10-15', '35', '25 -30', '15', '7', '8',
#        '15-20', '30', '35-40', '40-45', '33', '5-7', 'සති 7-8', '08-10',
#        '25-30', '10-12', '55-60', '5-6', '12-15', '18-20', 'මාස 05-06',
#        '6-8', '12', '20', '28-30', '8-25', 'මාස 03-05', '1', '8-9', '45',
#        '6', '9-10', '20-30', 'මාස 10', '03', '4-5', '8-10', '16',
#        'මාස 10-12', 'මාස 8', '2-3', '05', '10', 'මාස 02', 'මාස 5', 'nan',
#        '2,1/2', '30 - 35', '08 - 10', 'මාස 01', '15 - 20', '20 - 22',
#        '45 - 50', 'Unknown', '07', 'මාස 04', '40 - 45', '18', 'මාස 06',
#        '25 - 30', '15-18', '20 - 25', '5 - 6', 'මාස 06 - 07', 'මාස 2',
#        '4', '3-4', '6-7', '4-6', '5', '1,1/2-2', '22', '50', '6-10',
#        '1,1/2', '08', 'මාස 2 ක් පමණ', '3', '06', '60', '3,1/2', '21',
#        '01', 'මසක්', 'මාස: 8', '50 - 55', 'මාස: 8 - 9', '35 - 40', '40'],
#       dtype=object)

# %%
from numpy import nan
df['Age'] = df['Age'].replace({
   '25 -30':'25-30',
   'සති 7-8':'7.5 Weeks',
   'මාස 05-06':'5.5 Month',
   'මාස 03-05':'3.5 Months',
   'මාස 10-12':'11 Months',
   'මාස 10':'10 Months',
   'මාස 02':'2 Months',
   'මාස 5':'5 Months',
   'මාස 8':'8 Months',
   'මාස 06':'6 Months',
   'මාස 1':'1 Month',
   'මාස 01':'1 Month',
   '40 - 45':'40-45',
   '20 - 22':'20-22',
   'මාස 06 - 07':'6.5 months',
   ' - ':'Unknown',
   'මාස 6-8':'7 months',
   '1,1/2-2':'1.5-2',
   '2 1/2':'2.5',
   '12.15':'12-15',
   ' අවු: 20 මාස 6':'20.5',
   'මාස 2':'2 Months',
   '1 1/2':'1.5',
   '1,1/2':'1.5',
   'මාස 04':'4 months',
   'මසක්':'1 Month',
   'මාස: 8 - 9':'8.5 Months',
   'නොදනී':'Unknown',
   'මාස: 8':'8 Months',
   '2,1/2':'2.5',
   'මාස 2 ක් පමණ':'2 Months',
   '08':'9',
   '07':'7',
   '25 - 30':'25-30',
   '15 - 20':'15-20',
   '30 - 35':'30-35',
   '5 - 6':'5-6',
   '08-10':'8-10',
   '08 - 10':'08-10',
   '20 - 25':'20-25',
   '06':'6',
   '01':'1',
   '50-55':'50-55',
   '35 - 40':'35-40',
   '50 - 55':'50-55',
   '45 - 50':'45-50',
   '3,1/2':'3.5',
   'nan':'Unknown'
})

# %%
df['Age'].unique()
# Out:
# array(['20-25', '30-35', '25', '10-15', '35', '25-30', '15', '7', '8',
#        '15-20', '30', '35-40', '40-45', '33', '5-7', '7.5 Weeks', '8-10',
#        '10-12', '55-60', '5-6', '12-15', '18-20', '5.5 Month', '6-8',
#        '12', '20', '28-30', '8-25', '3.5 Months', '1', '8-9', '45', '6',
#        '9-10', '20-30', '10 Months', '03', '4-5', '16', '11 Months',
#        '8 Months', '2-3', '05', '10', '2 Months', '5 Months', 'Unknown',
#        '2.5', '08-10', '1 Month', '20-22', '45-50', '4 months', '18',
#        '6 Months', '15-18', '6.5 months', '4', '3-4', '6-7', '4-6', '5',
#        '1.5-2', '22', '50', '6-10', '1.5', '9', '3', '60', '3.5', '21',
#        '50-55', '8.5 Months', '40'], dtype=object)

# %%
import re
# Function to convert months and weeks to years
def convert_to_years(age_str):
    if isinstance(age_str, str):
        if re.match(r'^\d+(\.\d+)? Months?$', age_str):
            months = float(re.match(r'^\d+(\.\d+)?', age_str).group())
            return months / 12  # Approximate conversion to years
        elif re.match(r'^\d+ Weeks?$', age_str):
            weeks = int(re.match(r'^\d+', age_str).group())
            return weeks / 52  # Approximate conversion to years
        elif re.match(r'^\d+ Days?$', age_str):
            days = int(re.match(r'^\d+', age_str).group())
            return days / 365  # Approximate conversion to years
        elif '-' in age_str:
            age_range = age_str.split('-')
            try:
                return (float(age_range[0]) + float(age_range[1])) / 2  # Taking the average for range
            except ValueError:
                return None  # Invalid range
    try:
        return float(age_str)
    except ValueError:
        return None  # Unknown or invalid value

# Apply the conversion function to the 'Age' column
df['age'] = df['Age'].apply(convert_to_years)

# Function to categorize age
def categorize_age(age):
    if age is None or isinstance(age, str):
        return 'Unknown'
    elif age < 1:
        return 'Infant'
    elif age <= 4:
        return 'Calf'
    elif age <= 12:
        return 'Juvenile'
    elif age >=13:
        return 'Subadults and adults'
    else:
        return 'Unknown'

# Apply the function to the 'Age' column
df['Age Category'] = df['age'].apply(categorize_age)

# Drop the original 'Age' column if you don't need it anymore
df.drop(columns=['age'], inplace=True)

# %%
df.tail(50)
# Out:
#       No        Region      District       D/S Office Date of Death  \
# 219  220  Anuradhapura  Anuradhapura     Horowpathana    2016-10-08
# 220  221           Uva        Ampara          Madulla    2016-10-09
# 221  222      Vavuniya        Mannar     Manthai west    2016-10-10
# 222  223   Polonnaruwa   Polonnaruwa      Tamankaduwa    2016-10-10
# 223  224   Trincomalee   Trincomalee      Kuchchaveli    2016-10-13
# 224  225   Polonnaruwa        Matale        Vilgamuwa    2016-10-13
# 225  226       Wayamba    Kurunegala     Polpithigama    2016-10-16
# 226  227   Trincomalee   Trincomalee      Kuchchaveli    2016-10-17
# 227  228       Wayamba    Kurunegala        Galgamuwa    2016-10-19
# 228  229      Puttalam      Puttalam   Karuwalgaswewa    2016-10-22
# 229  230       Eastern        Ampara         Nintavur    2016-10-24
# 230  231  Anuradhapura  Anuradhapura          Thalawa    2016-10-24
# 231  232      Southern    Monaragala     Thanamalwila    2016-10-25
# ...

# %%
output_file_path = r'..\..\data\Cleaned_data\2016_clean.csv'

df.to_csv(output_file_path, index=False)
