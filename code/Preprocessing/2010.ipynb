# %%
'''from google.colab import drive
drive.mount('/content/drive')'''
# Out:
# "from google.colab import drive\ndrive.mount('/content/drive')"

# %%
import pandas as pd

# File path of the Excel file
file_path = r"D:\UOP\4th year\Research\cleaning\Dataset ele death\2010 Ele deaths.xlsx"

skip_rows=[0,155]
# Read the Excel file into a pandas DataFrame
df = pd.read_excel(file_path, skiprows=skip_rows)

# %%
df
# Out:
#       No       Region     District     D/S Office  Date of Death  \
# 0      1      Eastern       Ampara    Thirikkovil     12-01-2010
# 1      2      Eastern   Monaragala        Madulla     25-01-2010
# 2      3      Eastern       Ampara        Mahaoya     03-02-2010
# 3      4      Eastern       Ampara  Addalachchena     04-02-2010
# 4      5      Eastern       Ampara    Samanthurei     15-02-2010
# ..   ...          ...          ...            ...            ...
# 222  223  Polonnaruwa   Trincomale     Serunuwara     12-12-2010
# 223  224  Polonnaruwa  Polonnaruwa      Welikanda     13-12-2010
# 224  225  Polonnaruwa  Polonnaruwa   Hinguraggoda     19-12-2010
# 225  226  Polonnaruwa  Polonnaruwa   Madirigiriya     24-12-2010
# 226  227  Polonnaruwa  Polonnaruwa      Welikanda     25-12-2010
#
#           place of Death  Death of couse     sex   Age
# 0               Komaraiya       Gun shot  Female  15-20
# 1               Mullegama       Gun shot    Male  20-28
# 2                Pulaweli       Gun shot  Female  10-12
# 3        233 Kuburu place   Electrocuted    Male  30-35
# 4            Walathapitya       Gun shot  Female      6
# ..                    ...            ...     ...    ...
# 222  seruwila Somawathiya     Hakkapatas    Male  10-12
# 223            Muthuwalla        Unknown    Male  20-25
# 224  8064159 N - 8048040E        Unknown    Male     22
# 225       Palliyagodalla           Other  Female      3
# 226        Treekonamaduwa          Other    Male  15-20
#
# [227 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['No', 'Region', 'District', 'D/S Office', ' Date of Death',
#        ' place of Death ', 'Death of couse', 'sex', 'Age '],
#       dtype='object')

# %%
def replace_column_names(column_name):
    translations = {
        ' No': 'No',
        'D.S. Divition': 'D/S Office',
        ' Date of Death': 'Date of Death',
        'Death of couse': 'Cause of Death',
        ' place of Death ': 'Place of Death',
        'Age ':'Age',
        'sex':'Sex'
    }
    return translations.get(column_name, column_name)

# %%
df.rename(columns=replace_column_names, inplace=True)

# %%
df.columns
# Out:
# Index(['No', 'Region', 'District', 'D/S Office', 'Date of Death',
#        'Place of Death', 'Cause of Death', 'Sex', 'Age'],
#       dtype='object')

# %%
df = df.drop(columns=['Place of Death'])

# %%
df['Region'].unique()
# Out:
# array(['Eastern', 'Nothwestern', 'Central', 'YalaBundala', 'Southern',
#        'Polonnaruwa'], dtype=object)

# %%
df['Region'] = df['Region'].replace({
        'Nothwestern':'North Western'
})

# %%
df['Region'].unique()
# Out:
# array(['Eastern', 'North Western', 'Central', 'YalaBundala', 'Southern',
#        'Polonnaruwa'], dtype=object)

# %%
df[df['Region'].isnull()]
# Out:
# Empty DataFrame
# Columns: [No, Region, District, D/S Office, Date of Death, Cause of Death, Sex, Age]
# Index: []

# %%
df['District'].unique()
# Out:
# array(['Ampara', 'Monaragala', 'Baticola', 'Anuradhapura', 'Kurunagala',
#        'Puttalama', 'Mannar', nan, 'Puththalama', 'Trincomale', 'Vawniya',
#        'Anuradapura', 'Anuradhapuara ', 'Anuradhapura ', 'Badulla',
#        'kandy', 'Hambanthota', 'Rathnapura', 'Mathale', 'Polonnaruwa'],
#       dtype=object)

# %%
df['District'] = df['District'].replace({
        'Mathale': 'Matale',
        'Vawniya':'Vavuniya',
        'Mulathiw':'Mullaitivu',
        'Baticola':'Batticaloa',
        'Puttalama':'Puttalam',
        'Puththalama':'Puttalam',
        'Trincomale':'Trincomalee',
        'Kurunagala':'Kurunegala',
        'Rathnapura':'Ratnapura',
        'Hambanthota':'Hambantota',
        'Kilinochchiya':'Kilinochchi',
        'Anuradapura':'Anuradhapura',
        'Anuradhapura ':'Anuradhapura',
        'kandy':'Kandy',
        'Anuradhapuara ':'Anuradhapura'
})

# %%
df[df["District"].isnull()]
# Out:
#     No         Region District D/S Office Date of Death Cause of Death  \
# 51  52  North Western      NaN        NaN    08-03-2010        Poisned
# 53  54  North Western      NaN        NaN    21-03-2010       Accident
#
#         Sex    Age
# 51   Tusker  25-30
# 53   Female     15

# %%
df['District']=df['District'].fillna("Unknown")

# %%
df['District'].unique()
# Out:
# array(['Ampara', 'Monaragala', 'Batticaloa', 'Anuradhapura', 'Kurunegala',
#        'Puttalam', 'Mannar', 'Unknown', 'Trincomalee', 'Vavuniya',
#        'Badulla', 'Kandy', 'Hambantota', 'Ratnapura', 'Matale',
#        'Polonnaruwa'], dtype=object)

# %%
df['D/S Office'].unique()
# Out:
# array(['Thirikkovil', 'Madulla', 'Mahaoya', 'Addalachchena',
#        'Samanthurei', 'Pothuwil', 'Uhana', 'Lahugala', 'Chenkalladi',
#        'Wellaweli', 'Damana', 'Ampara', 'Madagama', 'Siyambalanduwa',
#        'Pothuvil', 'Wakarei', nan, 'Ipologama', 'Pannala', 'Silawathura',
#        'Thirappane', 'Mahawilachchiya', 'Ahatuwewa', 'Musali',
#        'Horowpothana', 'Palugaswewa', 'Nachchaduwa', 'Ambanpola',
#        'Palagala', 'Rambawa', 'Nawagaththegama', 'Madawachchiya',
#        'M.Nu.gampalatha', 'Galagamuwa', 'Galenbidunuwewa',
#        'Wanathavilluwa', 'Kakirawa', 'Padavi Sripura', 'Vawniya South',
#        'Pandulagama', 'Settikulama', 'Mahawa', 'Kahatagasdigiliya',
#        'Kabithigollawe', 'Omanthe', 'Galgamuwa', 'Ipalogama',
#        'Karuwalagaswewa', 'Padaviya', 'Kandakatiya', 'Ududumbara',
#        'Hambanthota', 'Thissamaharamaya', 'Thissa', 'Lunugamwehera',
#        'Kataragama', 'Thanamalvila', 'Wellawaya', 'Haldumulla',
#        'Buththala', 'Wallawaya', 'Sooriyawewa', 'Ambalanthota',
#        'Embilipitiya', 'Weligepola', 'Dambulla', 'Hinguraggoda',
#        'Kuchchaweli', 'Kanthale', 'Wilgamuwa', 'Dehiaththakandiya',
#        'Padiyathalawa', 'Elahara', 'Serunuwara', 'Mahiyanganaya',
#        'Dimbulagala', 'Morawewa', 'Welikanda', 'Kinniya', 'Laggala',
#        'Vilgamuwa', 'Madirigiriya', 'Gomarankadawela',
#        'Nagara  ha Kadawath', 'Alahara', 'Thamankaduwa'], dtype=object)

#        '11-12-2010', '12-12-2010', '13-12-2010', '19-12-2010'],
#       dtype=object)

# %%
# Convert the date column to pandas datetime format
#df['Date of Death'] = pd.to_datetime(df['Date of Death'])

df['Date of Death'] = pd.to_datetime(df['Date of Death'], format='%d-%m-%Y')

# %%
df['Date of Death'].unique()
# Out:
# <DatetimeArray>
# ['2010-01-12 00:00:00', '2010-01-25 00:00:00', '2010-02-03 00:00:00',
#  '2010-02-04 00:00:00', '2010-02-15 00:00:00', '2010-02-21 00:00:00',
#  '2010-02-24 00:00:00', '2010-02-25 00:00:00', '2010-02-27 00:00:00',
#  '2010-03-01 00:00:00',
#  ...
#  '2010-10-12 00:00:00', '2010-10-13 00:00:00', '2010-10-17 00:00:00',
#  '2010-10-18 00:00:00', '2010-11-03 00:00:00', '2010-11-10 00:00:00',
#  '2010-12-11 00:00:00', '2010-12-12 00:00:00', '2010-12-13 00:00:00',
#  '2010-12-19 00:00:00']
# Length: 156, dtype: datetime64[ns]

# %%
df = df.sort_values(by='Date of Death').reset_index(drop=True)

# %%
df
# Out:
#       No         Region      District       D/S Office Date of Death  \
# 0    119       Southern    Monaragala       Kataragama    2010-01-01
# 1    120       Southern    Monaragala     Thanamalvila    2010-01-07
# 2     43  North Western  Anuradhapura          Unknown    2010-01-08
# 3      1        Eastern        Ampara      Thirikkovil    2010-01-12
# 4     44  North Western    Kurunegala        Ipologama    2010-01-15
# ..   ...            ...           ...              ...           ...
# 222  227    Polonnaruwa   Polonnaruwa        Welikanda    2010-12-25
# 223  153       Southern     Ratnapura     Embilipitiya    2010-12-29
# 224  108  North Western      Puttalam  Nawagaththegama    2010-12-29
# 225   42        Eastern        Ampara         Pothuvil    2010-12-29
# 226  110        Central         Kandy       Ududumbara    2010-12-31
#
#       Cause of Death              Sex      Age
# 0    Body distroied              Male    50-55
# 1            Unknown             Male       20
# 2       Electrocuted  Tusker (1 Tusk)    30-35
# 3           Gun shot           Female    15-20
# 4           Accident     Male (child)        5
# ..               ...              ...      ...
# 222            Other             Male    15-20
# 223          Unknown             Male  1 Month
# 224         Gun shot             Male    35-40
# 225     Electrocuted             Male    25-30
# 226          Poisned           Female       45
#
# [227 rows x 8 columns]

# %%
df['No'] = df.index + 1

# %%
df
# Out:
#       No         Region      District       D/S Office Date of Death  \
# 0      1       Southern    Monaragala       Kataragama    2010-01-01
# 1      2       Southern    Monaragala     Thanamalvila    2010-01-07
# 2      3  North Western  Anuradhapura          Unknown    2010-01-08
# 3      4        Eastern        Ampara      Thirikkovil    2010-01-12
# 4      5  North Western    Kurunegala        Ipologama    2010-01-15
# ..   ...            ...           ...              ...           ...
# 222  223    Polonnaruwa   Polonnaruwa        Welikanda    2010-12-25
# 223  224       Southern     Ratnapura     Embilipitiya    2010-12-29
# 224  225  North Western      Puttalam  Nawagaththegama    2010-12-29
# 225  226        Eastern        Ampara         Pothuvil    2010-12-29
# 226  227        Central         Kandy       Ududumbara    2010-12-31
#
#       Cause of Death              Sex      Age
# 0    Body distroied              Male    50-55
# 1            Unknown             Male       20
# 2       Electrocuted  Tusker (1 Tusk)    30-35
# 3           Gun shot           Female    15-20
# 4           Accident     Male (child)        5
# ..               ...              ...      ...
# 222            Other             Male    15-20
# 223          Unknown             Male  1 Month
# 224         Gun shot             Male    35-40
# 225     Electrocuted             Male    25-30
# 226          Poisned           Female       45
#
# [227 rows x 8 columns]

# %%
df['Cause of Death'].unique()
# Out:
# array(['Body distroied ', 'Unknown', 'Electrocuted', 'Gun shot',
#        'Accident', 'Train Accident', nan, 'Broken to front Write hand',
#        'Poisned', 'Other', 'Hakkapatas', 'Natural', 'Septasimiya',
#        'Land mine', 'Body Distroied ', 'Body distroyed', 'Distroied body'],
#       dtype=object)

# %%
def replace_word(text):
    translations = {
    'Gun shot':'Gunshot',
    'Other       ':'Other',
    'Broken th Spinal Cord':'Broken the Spinal',
    'Poisned':'Poisned',
    'Broken to front Write hand':'Injured',
    'Septasimiya':'Septicemia',
    '3 months ago':'Unknown',
    'Unknoun':'Unknown',
    'Eletrocted':'Electrocuted',
    'Electrocted':'Electrocuted',
    'Old Injurice& Poisned':'Poisned',
    'Drowning':'Drowned',
    'Body distroied ':'Body destroyed',
    'Body Distroied':'Body destroyed',
    'Body distroyed':'Body destroyed',
    'Body Distroied ':'Body destroyed',
    'Distroied body':'Body destroyed',

    'Dipniya':'Other',
    'consuption of garbage':'Garbage consumption'
    }
    return translations.get(text, text)

# %%
df["Cause of Death"] = df["Cause of Death"].apply(replace_word)

# %%
df['Cause of Death'] = df['Cause of Death'].fillna('Unknown')

# %%
df['Cause of Death'].unique()
# Out:
# array(['Body destroyed', 'Unknown', 'Electrocuted', 'Gunshot', 'Accident',
#        'Train Accident', 'Injured', 'Poisned', 'Other', 'Hakkapatas',
#        'Natural', 'Septicemia', 'Land mine'], dtype=object)

# %%
df
# Out:
#       No         Region      District       D/S Office Date of Death  \
# 0      1       Southern    Monaragala       Kataragama    2010-01-01
# 1      2       Southern    Monaragala     Thanamalvila    2010-01-07
# 2      3  North Western  Anuradhapura          Unknown    2010-01-08
# 3      4        Eastern        Ampara      Thirikkovil    2010-01-12
# 4      5  North Western    Kurunegala        Ipologama    2010-01-15
# ..   ...            ...           ...              ...           ...
# 222  223    Polonnaruwa   Polonnaruwa        Welikanda    2010-12-25
# 223  224       Southern     Ratnapura     Embilipitiya    2010-12-29
# 224  225  North Western      Puttalam  Nawagaththegama    2010-12-29
# 225  226        Eastern        Ampara         Pothuvil    2010-12-29
# 226  227        Central         Kandy       Ududumbara    2010-12-31
#
#      Cause of Death              Sex      Age
# 0    Body destroyed             Male    50-55
# 1           Unknown             Male       20
# 2      Electrocuted  Tusker (1 Tusk)    30-35
# 3           Gunshot           Female    15-20
# 4          Accident     Male (child)        5
# ..              ...              ...      ...
# 222           Other             Male    15-20
# 223         Unknown             Male  1 Month
# 224         Gunshot             Male    35-40
# 225    Electrocuted             Male    25-30
# 226         Poisned           Female       45
#
# [227 rows x 8 columns]

# %%
df['Sex'].unique()
# Out:
# array(['Male', 'Tusker (1 Tusk)', 'Female', 'Male (child)', 'Unknown',
#        ' Tusker', 'Children', nan, 'male', '1,1/2', 'Tusker',
#        'Tusker Child'], dtype=object)

# %%
df['Sex'] = df['Sex'].replace({
    'male':'Male',
    'Male (child)':'Male',
    ' Tusker':'Male',
    'Tusker (1 Tusk)':'Male',
    '1,1/2':'Calf',
    'Children':'Calf',
    'Tusker Child':'Male',
    'Tusker':'Male'
})

# %%
df['Sex'] = df['Sex'].fillna('Unknown')

# %%
df['Sex'].unique()
# Out:
# array(['Male', 'Female', 'Unknown', 'Calf'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array(['50-55', '20', '30-35', '15-20', '5', '35-40', '20-25', '7',
#        '20-28', '10-12', '15', '40-50', '6', '25-30', '30', '40-45', '4',
#        '2-4', '18-20', '1 Month', '45', '25', '12', '14', '50', '12-15',
#        '18', nan, '6 Months', '6-7', '03', '55', '6-8', '5-6', '35',
#        '15-18', '1', 'Male', '2 Weeks', 30, '8', '10', '32', '4-5',
#        '26-28', '2', '20-22', '03-04', '8-10', '05-06', '2,1/2', '17',
#        '5-6 Month', '30-33', '3-4', '50-60', '3 Month', '17-18', '10-15',
#        '60-65', '3 Months', '4,1/2', '3,1/2', 35, 8, 10, '30.-35', 25,
#        '22', '3'], dtype=object)

# %%
from numpy import nan
df['Age'] = df['Age'].replace({
    '3 Month':'3 Months',
    '30.-35':'30-35',
    '03-04':'3-4',
    '03':'3',
    '05-06':'5-6',
    '5-6 Month':'5.5 Months',
    '2,1/2':'2.5',
    '4,1/2':'4.5',
    '3,1/2':'3.5'


})

# %%
df['Age'] = df['Age'].fillna('Unknown')

# %%
df[df['Age']=='5.5 Months']
# Out:
#       No         Region    District D/S Office Date of Death Cause of Death  \
# 150  151  North Western  Kurunegala  Ahatuwewa    2010-09-22       Accident
#
#       Sex         Age
# 150  Male  5.5 Months

# %%
df['Age'].unique()
# Out:
# array(['50-55', '20', '30-35', '15-20', '5', '35-40', '20-25', '7',
#        '20-28', '10-12', '15', '40-50', '6', '25-30', '30', '40-45', '4',
#        '2-4', '18-20', '1 Month', '45', '25', '12', '14', '50', '12-15',
#        '18', 'Unknown', '6 Months', '6-7', '3', '55', '6-8', '5-6', '35',
#        '15-18', '1', 'Male', '2 Weeks', 30, '8', '10', '32', '4-5',
#        '26-28', '2', '20-22', '3-4', '8-10', '2.5', '17', '5.5 Months',
#        '30-33', '50-60', '3 Months', '17-18', '10-15', '60-65', '4.5',
#        '3.5', 35, 8, 10, 25, '22'], dtype=object)

# %%
import re
# Function to convert months and weeks to years
def convert_to_years(age_str):
    if isinstance(age_str, str):
        if re.match(r'^\d+(\.\d+)? Months?$', age_str):
            months = float(re.match(r'^\d+(\.\d+)?', age_str).group())
            return months / 12  # Approximate conversion to years
        elif re.match(r'^\d+ Weeks?$', age_str):
            weeks = int(re.match(r'^\d+', age_str).group())
            return weeks / 52  # Approximate conversion to years
        elif re.match(r'^\d+ Days?$', age_str):
            days = int(re.match(r'^\d+', age_str).group())
            return days / 365  # Approximate conversion to years
        elif '-' in age_str:
            age_range = age_str.split('-')
            try:
                return (float(age_range[0]) + float(age_range[1])) / 2  # Taking the average for range
            except ValueError:
                return None  # Invalid range
    try:
        return float(age_str)
    except ValueError:
        return None  # Unknown or invalid value

# Apply the conversion function to the 'Age' column
df['age'] = df['Age'].apply(convert_to_years)

# Function to categorize age
def categorize_age(age):
    if age is None or isinstance(age, str):
        return 'Unknown'
    elif age < 1:
        return 'Infant'
    elif age <= 4:
        return 'Calf'
    elif age <= 12:
        return 'Juvenile'
    elif age >=13:
        return 'Subadults and adults'
    else:
        return 'Unknown'

# Apply the function to the 'Age' column
df['Age Category'] = df['age'].apply(categorize_age)

# Drop the original 'Age' column if you don't need it anymore
df.drop(columns=['age'], inplace=True)

# %%
df['Age Category'].unique()
# Out:
# array(['Subadults and adults', 'Juvenile', 'Calf', 'Infant', 'Unknown'],
#       dtype=object)

# %%
df.tail(50)
# Out:
#       No         Region      District         D/S Office Date of Death  \
# 177  178    Polonnaruwa   Polonnaruwa            Alahara    2010-11-01
# 178  179  North Western  Anuradhapura  Kahatagasdigiliya    2010-11-01
# 179  180        Eastern        Ampara              Uhana    2010-11-01
# 180  181    YalaBundala    Monaragala         Kataragama    2010-11-02
# 181  182    Polonnaruwa   Polonnaruwa       Thamankaduwa    2010-11-03
# 182  183       Southern    Hambantota      Lunugamwehera    2010-11-04
# 183  184  North Western  Anuradhapura     Kabithigollawe    2010-11-05
# 184  185  North Western  Anuradhapura     Kabithigollawe    2010-11-05
# 185  186  North Western        Mannar        Settikulama    2010-11-05
# 186  187    YalaBundala    Hambantota   Thissamaharamaya    2010-11-09
# 187  188    Polonnaruwa   Polonnaruwa        Dimbulagala    2010-11-09
# 188  189    Polonnaruwa   Trincomalee           Kanthale    2010-11-10
# 189  190  North Western  Anuradhapura  Kahatagasdigiliya    2010-11-14
# 190  191    Polonnaruwa   Trincomalee    Gomarankadawela    2010-11-15
# 191  192  North Western  Anuradhapura       Horowpothana    2010-11-15
# 192  193  North Western  Anuradhapura      Madawachchiya    2010-11-17
# 193  194       Southern    Monaragala       Thanamalvila    2010-11-20
# 194  195  North Western      Vavuniya            Omanthe    2010-11-20
# 195  196    Polonnaruwa   Trincomalee           Morawewa    2010-11-21
# 196  197  North Western  Anuradhapura       Horowpothana    2010-11-21
# 197  198  North Western    Kurunegala          Galgamuwa    2010-11-23
# 198  199        Eastern        Ampara      Addalachchena    2010-11-27
# 199  200       Southern    Monaragala       Thanamalvila    2010-11-30
# 200  201    Polonnaruwa   Trincomalee         Serunuwara    2010-12-03
# 201  202  North Western  Anuradhapura          Ipalogama    2010-12-03
# 202  203  North Western  Anuradhapura         Thirappane    2010-12-03
# 203  204  North Western  Anuradhapura    M.Nu.gampalatha    2010-12-03
# 204  205        Eastern    Monaragala            Madulla    2010-12-04
# 205  206        Eastern    Batticaloa            Wakarei    2010-12-04
# 206  207    Polonnaruwa   Polonnaruwa          Welikanda    2010-12-04
# 207  208  North Western      Puttalam    Karuwalagaswewa    2010-12-05
# 208  209  North Western    Kurunegala          Galgamuwa    2010-12-06
# 209  210  North Western        Mannar             Musali    2010-12-06
# 210  211  North Western      Puttalam    Karuwalagaswewa    2010-12-09
# 211  212    Polonnaruwa   Polonnaruwa       Thamankaduwa    2010-12-09
# 212  213    Polonnaruwa   Polonnaruwa        Dimbulagala    2010-12-11
# 213  214    Polonnaruwa   Trincomalee         Serunuwara    2010-12-12
# 214  215    Polonnaruwa   Polonnaruwa          Welikanda    2010-12-13
# 215  216    Polonnaruwa   Polonnaruwa       Hinguraggoda    2010-12-19
# 216  217        Eastern        Ampara            Mahaoya    2010-12-20
# 217  218       Southern    Monaragala       Thanamalvila    2010-12-20
# 218  219  North Western  Anuradhapura           Padaviya    2010-12-20
# 219  220       Southern    Hambantota        Hambanthota    2010-12-24
# 220  221    Polonnaruwa   Polonnaruwa       Madirigiriya    2010-12-24
# 221  222  North Western  Anuradhapura       Horowpothana    2010-12-25
# 222  223    Polonnaruwa   Polonnaruwa          Welikanda    2010-12-25
# 223  224       Southern     Ratnapura       Embilipitiya    2010-12-29
# 224  225  North Western      Puttalam    Nawagaththegama    2010-12-29
# 225  226        Eastern        Ampara           Pothuvil    2010-12-29
# 226  227        Central         Kandy         Ududumbara    2010-12-31
#
#      Cause of Death      Sex       Age          Age Category
# 177         Unknown   Female     20-25  Subadults and adults
# 178         Poisned     Male        25  Subadults and adults
# 179    Electrocuted     Male     35-40  Subadults and adults
# 180           Other     Male        50  Subadults and adults
# 181         Unknown     Male     25-30  Subadults and adults
# 182    Electrocuted   Female        25  Subadults and adults
# 183        Accident   Female        30  Subadults and adults
# 184         Gunshot   Female         4                  Calf
# 185      Hakkapatas     Male         6              Juvenile
# 186    Electrocuted     Male        30  Subadults and adults
# 187         Unknown     Male        35  Subadults and adults
# 188         Unknown  Unknown     25-30  Subadults and adults
# 189         Unknown  Unknown   Unknown               Unknown
# 190  Body destroyed     Male       3-4                  Calf
# 191         Poisned     Male       4.5              Juvenile
# 192      Hakkapatas     Male       2.5                  Calf
# 193         Gunshot     Male        30  Subadults and adults
# 194      Hakkapatas     Male       3.5                  Calf
# 195  Body destroyed     Male     25-30  Subadults and adults
# 196         Unknown  Unknown   Unknown               Unknown
# 197        Accident     Male        35  Subadults and adults
# 198         Gunshot     Male     30-35  Subadults and adults
# 199    Electrocuted     Male     40-45  Subadults and adults
# 200      Hakkapatas     Male     15-20  Subadults and adults
# 201      Hakkapatas     Male         8              Juvenile
# 202      Hakkapatas     Male        10              Juvenile
# 203    Electrocuted     Male        30  Subadults and adults
# 204  Body destroyed     Male     30-35  Subadults and adults
# 205         Gunshot   Female     10-12              Juvenile
# 206           Other     Male        35  Subadults and adults
# 207           Other   Female  6 Months                Infant
# 208        Accident  Unknown     10-15               Unknown
# 209      Hakkapatas     Male        25  Subadults and adults
# 210           Other   Female     40-50  Subadults and adults
# 211         Unknown     Male         2                  Calf
# 212         Poisned     Male         4                  Calf
# 213      Hakkapatas     Male     10-12              Juvenile
# 214         Unknown     Male     20-25  Subadults and adults
# 215         Unknown     Male        22  Subadults and adults
# 216         Gunshot     Male     30-35  Subadults and adults
# 217         Unknown     Male        35  Subadults and adults
# 218         Gunshot     Male        30  Subadults and adults
# 219  Body destroyed  Unknown   Unknown               Unknown
# 220           Other   Female         3                  Calf
# 221         Unknown     Male        15  Subadults and adults
# 222           Other     Male     15-20  Subadults and adults
# 223         Unknown     Male   1 Month                Infant
# 224         Gunshot     Male     35-40  Subadults and adults
# 225    Electrocuted     Male     25-30  Subadults and adults
# 226         Poisned   Female        45  Subadults and adults

# %%
output_file_path = r'D:\UOP\4th year\Research\cleaning\Dataset ele death\cleaned\2010_clean.csv'

df.to_csv(output_file_path, index=False)
