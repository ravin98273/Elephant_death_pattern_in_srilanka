# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'..\..\data\Cleaned_data\cancat.csv')

# %%
df[df['District']=='Ratnapura']
# Out:
#         No                 Region   District    D/S Office Date of Death  \
# 121    122               Southern  Ratnapura  Embilipitiya    2010-08-11
# 162    163               Southern  Ratnapura    Weligepola    2010-10-08
# 223    224               Southern  Ratnapura  Embilipitiya    2010-12-29
# 227    228               Southern  Ratnapura  Embilipitiya    2011-01-03
# 228    229               Southern  Ratnapura     Balangoda    2011-01-04
# ...    ...                    ...        ...           ...           ...
# 1821  1822  Elephant Transit Home  Ratnapura       Unknown    2017-09-30
# 1829  1830               Southern  Ratnapura  Ambilipitiya    2017-10-13
# 1845  1846  Elephant Transit Home  Ratnapura       Unknown    2017-10-30
# 1889  1890  Elephant Transit Home  Ratnapura       Unknown    2017-12-28
# 1890  1891               Southern  Ratnapura    Weligepola    2017-12-28
#
#       Cause of Death     Sex       Age          Age Category
# ...

# %%
shapefile_path = r'..\..\data\Map_file\LKA_adm2.shp'

gdf = gpd.read_file(shapefile_path)


# Plot the data
gdf.plot()
fig = plt.gcf()
fig.set_size_inches(13, 13)
# Show the plot
plt.show()

# %%
gdf['NAME_2'].unique()
# Out:
# array(['Addalachchenai', 'Akkaraipattu', 'Alayadiwembu', 'Ampara',
#        'Damana', 'Dehiattakandiya', 'Eragama', 'Kalmunai', 'Karativu',
#        'Lahugala', 'Mahaoya', 'Navithanveli', 'Ninthavur',
#        'Padiyathalawa', 'Pothuvil', 'Sainthamarathu', 'Samanthurai',
#        'Thirukkovil', 'Uhana', 'Galenbindunuwewa', 'Galnewa',
#        'Horowpothana', 'Ipalogama', 'Kahatagasdigiliya', 'Kebithigollewa',
#        'Kekirawa', 'Maha Vilachchiya', 'Medawachchiya', 'Mihinthale',
#        'N. Palatha Central', 'N. Palatha East', 'Nachchadoowa',
#        'Nochchiyagama', 'Padaviya', 'Palagala', 'Palugaswewa',
#        'Rajanganaya', 'Rambewa', 'Thalawa', 'Thambuttegama', 'Thirappane',
#        'Badulla', 'Bandarawela', 'Ella', 'Hali-Ela', 'Haputale',
#        'Hildummulla', 'Kandaketiya', 'Lunugala', 'Mahiyanganaya',
#        'Meegahakivula', 'Passara', 'Rideemaliyadda', 'Soranathota',
#        'Uva Paranagama', 'Welimada', 'Eravur Pattu', 'Eravur Town',
# ...

# %%
df['D/S Office'].unique()
# Out:
# array(['Kataragama', 'Thanamalvila', 'Unknown', 'Thirikkovil',
#        'Ipologama', 'Pannala', 'Madulla', 'Wellawaya', 'Mahaoya',
#        'Dambulla', 'Addalachchena', 'Ahatuwewa', 'Hinguraggoda', 'Musali',
#        'Samanthurei', 'Thirappane', 'Haldumulla', 'Silawathura',
#        'Pothuwil', 'Uhana', 'Mahawilachchiya', 'Kuchchaweli', 'Lahugala',
#        'Kanthale', 'Wilgamuwa', 'Hambanthota', 'Dehiaththakandiya',
#        'Chenkalladi', 'Padiyathalawa', 'Buththala', 'Elahara',
#        'Horowpothana', 'Serunuwara', 'Wellaweli', 'Mahiyanganaya',
#        'Dimbulagala', 'Palugaswewa', 'Morawewa', 'Wallawaya', 'Damana',
#        'Welikanda', 'Sooriyawewa', 'Nachchaduwa', 'Ambanpola', 'Palagala',
#        'Rambawa', 'Ampara', 'Nawagaththegama', 'Madagama',
#        'Madawachchiya', 'Siyambalanduwa', 'Thissamaharamaya',
#        'M.Nu.gampalatha', 'Kinniya', 'Galagamuwa', 'Galenbidunuwewa',
#        'Ambalanthota', 'Laggala', 'Kandakatiya', 'Vilgamuwa',
# ...

# %%
unique_values_df = df['D/S Office'].unique()
unique_values_gdf = gdf['NAME_2'].unique()

# Check if the unique values in the two columns are the same
if set(unique_values_df) == set(unique_values_gdf):
    print("The unique values in 'D/S Office' and 'NAME_2' are the same.")
else:
    print("The unique values in 'D/S Office' and 'NAME_2' are different.")
# Out:
# The unique values in 'D/S Office' and 'NAME_2' are different.

# %%
unique_values_df = set(df['D/S Office'].unique())
unique_values_gdf = set(gdf['NAME_2'].unique())

# Find the values that are unique to each set
unique_to_df = unique_values_df - unique_values_gdf
unique_to_gdf = unique_values_gdf - unique_values_df

print("Unique values in 'D/S Office' not in 'NAME_2':", unique_to_df)
print("Unique values in 'NAME_2' not in 'D/S Office':", unique_to_gdf)
# Out:
# Unique values in 'D/S Office' not in 'NAME_2': {'Trincomalee', 'Akkarepaththuwa', 'Settikulam', 'Pattipalei', 'Karuwalagaswawa', 'wellawaya', 'Wavnathiw', 'Madadumbara', 'Mulankavil', 'Wallachchena', 'Madawachchiya', 'Tirappane', 'Vawniya', 'Puttalama', 'Ma:Nu: Gampalatha', 'Thissamaharamaya', 'Uhana, damana', 'Manampitiya', 'Rambawa', 'Wavniya Southern', 'Do', 'Nachchaduwa', 'Ipologama', 'Dehiaththakandiya', 'Sooriyawawa', 'Gomarankadawela', 'Haldhummulla', 'Galkiriyagama', 'Nagara ha Kadawath', 'Kinnya', 'Madagama', 'Madhirigiriya', 'Puttlam', 'Elahara', 'Unknown', 'Galagamuwa', 'No report', 'Wawunathiw', 'Nikawartiya', 'Ambilipitiya', 'Mathale', 'Ahetuwewa', 'Sampathnuwara', 'Adampan', 'Thambalagamuwa', 'Horowpathana', 'nanattan', 'Nagara  ha Kadawath', 'Bibila', 'Wellawali', 'Vilgamuwa', 'Madwachchiya', 'Dimbulagala, Aralaganvila', 'siyabalanduwa', 'Madavachchiya', 'Ahatuwawa', 'Wavniya north', 'Monaragala', 'Mahawilachchiya', 'Kandakatiya', 'Nedunkarny', 'Welkanda', 'Sevangala',
# ...

# %%
unique_values_df = set(df['D/S Office'].unique())
unique_values_gdf = set(gdf['NAME_2'].unique())

# Find the values that are common to both sets
common_values = unique_values_df.intersection(unique_values_gdf)

print("Common values in 'D/S Office' and 'NAME_2':", common_values)
# Out:
# Common values in 'D/S Office' and 'NAME_2': {'Kebithigollewa', 'Thanamalvila', 'Weligepola', 'Kinniya', 'Padiyathalawa', 'Elahera', 'Dehiattakandiya', 'Katharagama', 'Mihinthale', 'Dambulla', 'Damana', 'Minipe', 'Alayadiwembu', 'Musali', 'Madulla', 'Lahugala', 'Thalawa', 'Palugaswewa', 'Mahawa', 'Walapane', 'Ambanpola', 'Ambalanthota', 'Thamankaduwa', 'Ambagamuwa', 'Kahatagasdigiliya', 'Naula', 'Nochchiyagama', 'Hanguranketha', 'Palagala', 'Thirappane', 'Horowpothana', 'Mahaoya', 'Oddusuddan', 'Buttala', 'Anamaduwa', 'Hingurakgoda', 'Thissamaharama', 'Udadumbara', 'Karuwalagaswewa', 'Ampara', 'Welikanda', 'Samanthurai', 'Thunukkai', 'Dimbulagala', 'Pothuvil', 'Kekirawa', 'Polpithigama', 'Kuchchaveli', 'Mahiyanganaya', 'Morawewa', 'Sevanagala', 'Giribawa', 'Balangoda', 'Eragama', 'Nikaweratiya', 'Padaviya', 'Galenbindunuwewa', 'Hambantota', 'Verugal', 'Kotavehera', 'Ipalogama', 'Pannala', 'Wilgamuwa', 'Puttalam', 'Sooriyawewa', 'Embilipitiya', 'Uhana', 'Wellawaya', 'Gomarankadawala', 
# ...

# %%
replacement_dict = {
    'Dabulla':'Dambulla',
    'Kataragama': 'Katharagama',
    'Thanamalvila': 'Thanamalvila',
    'Thirikkovil': 'Thirukkovil',
    'Ipologama': 'Ipalogama',
    'Addalachchena': 'Addalachchenai',
    'Ahatuwewa': 'Ehetuwewa',
    'Hinguraggoda': 'Hingurakgoda',
    'Samanthurei': 'Samanthurai',
    'Haldumulla': 'Hildummulla',
    'Silawathura': 'Mannar Town',
    'Pothuwil': 'Pothuvil',
    'Mahawilachchiya': 'Maha Vilachchiya',
    'Kuchchaweli': 'Kuchchaveli',
    'Kanthale': 'Kantalai',
    'Hambanthota': 'Hambantota',
    'Dehiaththakandiya': 'Dehiattakandiya',
    'Chenkalladi': 'Manmunai South and Eruvilpattu',
    'Buththala': 'Buttala',
    'Elahara': 'Elahera',
    'Serunuwara': 'Seruvila',
    'Wellaweli': 'Porativu Pattu',
    'Wallawaya': 'Wellawaya',
    'Nachchaduwa': 'Nachchadoowa',
    'Rambawa': 'Rambewa',
    'Nawagaththegama': 'Nawagattegama',
    'Madagama': 'Medagama',
    'Madawachchiya': 'Medawachchiya',
    'Thissamaharamaya': 'Thissamaharama',
    'M.Nu.gampalatha': 'N. Palatha Central',
    'Galagamuwa': 'Galgamuwa',
    'Galenbidunuwewa': 'Galenbindunuwewa',
    'Laggala': 'Laggala-Pallegama',
    'Kandakatiya': 'Kandaketiya',
    'Vilgamuwa': 'Wilgamuwa',
    'Lunugamwehera': 'Lunugamvehera',
    'Thissa': 'Thissamaharama',
    'Wanathavilluwa': 'Vanathavilluwa',
    'Madirigiriya': 'Medirigiriya',
    'Gomarankadawela': 'Gomarankadawala',
    'Kakirawa': 'Kekirawa',
    'Padavi Sripura': 'Padavi Sri Pura',
    'Vawniya South': 'Vavuniya South',
    'Pandulagama': 'Palagala',
    'Settikulama': 'Vengalacheddiculam',
    'Nagara  ha Kadawath': 'Trincomalee Town and Gravets',
    'Alahara': 'Elahera',
    'Kabithigollawe': 'Kebithigollewa',
    'Omanthe': 'Vavuniya',
    'Wakarei': 'Koralai Pattu North',
    'Padaviya': 'Padaviya',
    'Ududumbara': 'Udadumbara',
    'Ma: Nu: gampalatha': 'N. Palatha Central',
    'Chencalladi': 'Eravur Pattu',
    'Ehatuwewa': 'Ehetuwewa',
    'Hambanthaota': 'Hambantota',
    'Wakare': 'Koralai Pattu North',
    'Wavniya': 'Vavuniya',
    'Muthur': 'Muttur',
    'Wanathawilluwa': 'Vanathavilluwa',
    'Eluwankulama': 'Nochchiyagama',
    'Werugal': 'Verugal',
    'Nagara ha Kadawath': 'Trincomalee Town and Gravets',
    'Manampitiya': 'Dimbulagala',
    'Ridimaliyadda': 'Rideemaliyadda',
    'Siyamanduwa': 'Siyambalanduwa',
    'Kinnya': 'Kinniya',
    'Wallachchena': 'Koralai Pattu (Valachchenai)',
    'Korelepattu North': 'Koralai Pattu North',
    'Buththlala': 'Buttala',
    'Puttalama': 'Puttalam',
    'Do': 'Kurunegala',
    'Wavniya North': 'Vavuniya North',
    'Kotawehera': 'Kotavehera',
    'Haldummulla': 'Hildummulla',
    'Sampathnuwara': 'Padaviya',
    'No report': 'Unknown',
    'Thanthirimale': 'Maha Vilachchiya',
    'Ma:Nu: Gampalatha': 'N. Palatha Central',
    'Mankulama': 'Oddusuddan',
    'Mulathiw': 'Maritimepattu',
    'wellawaya': 'Wellawaya',
    'Oddusudan': 'Oddusuddan',
    'Ma.Nu. Gampalatha': 'N. Palatha Central',
    'Abilipitiya': 'Embilipitiya',
    'Wavniya Southern': 'Vavuniya South',
    'Villachchiya': 'Maha Vilachchiya',
    'Nanattan': 'Nanaddan',
    'Madhirigiriya': 'Medirigiriya',
    'Kiran': 'Koralai Pattu (Valachchenai)',
    'Potkerny': 'Porativu Pattu',
    'Puttlam': 'Puttalam',
    'Badalkubura': 'Badalkumbura',
    'Vawniya': 'Vavuniya',
    'Mahavilachchiya': 'Maha Vilachchiya',
    'Welioya': 'Padaviya',
    'Sevangala': 'Sevanagala',
    'Wavniya South': 'Vavuniya South',
    'Ma nu gampalatha': 'N. Palatha Central',
    'Wavniya ': 'Vavuniya',
    'serunuwara': 'Seruvila',
    'Pothuvill': 'Pothuvil',
    'Nikawartiya': 'Nikaweratiya',
    'Mahiyangana': 'Mahiyanganaya',
    'Welkanda': 'Welikanda',
    'Madadumbara': 'Medadumbara',
    'Bibila': 'Bibile',
    'Vilachchiya': 'Maha Vilachchiya',
    'Kabithigollawa': 'Kebithigollewa',
    'Marawewa': 'Morawewa',
    'madirigiriya': 'Medirigiriya',
    'Madwachchiya': 'Medawachchiya',
    'Ahatuwawa': 'Ehetuwewa',
    'Thambalagamuwa': 'Thampalakamam',
    'Sooriyawawa': 'Sooriyawewa',
    'Nananttan': 'Nanaddan',
    'Manthei West': 'Manthai West',
    'Wavniya north': 'Vavuniya North',
    'Galnawa': 'Galnewa',
    'Karuwalagaswawa': 'Karuwalagaswewa',
    'siyabalanduwa': 'Siyambalanduwa',
    'Wavnathiw': 'Manmunai West',
    'Nawagathegama': 'Nawagattegama',
    'Pudukuduiruppu': 'Puthukudiyiruppu',
    'Ma: Nu gampalatha': 'N. Palatha Central',
    'Monaragala': 'Moneragala',
    'Walachchena Central': 'Koralai Pattu (Valachchenai)',
    'Pattipola': 'Manmunai South-West',
    'Madu': 'Madhu',
    'Ahetuwewa': 'Ehetuwewa',
    'Chenkaladi': 'Eravur Pattu',
    'Dimbulagala, Aralaganvila': 'Dimbulagala',
    'Akkarepaththuwa': 'Akkaraipattu',
    'Kandamalawa': 'Gomarankadawala',
    'Uhana, damana': 'Uhana',
    'Minipe, Hasalaka': 'Minipe',
    'Trincomalee': 'Trincomalee Town and Gravets',
    'Siyabalanduwa': 'Siyambalanduwa',
    'Nedunkarny': 'Vavuniya North',
    'Settikulam': 'Vengalacheddiculam',
    'Kanagarayankulam': 'Vavuniya North',
    'Wawnathiu': 'Manmunai West',
    'Kuchchaweli ': 'Kuchchaveli',
    'Suriyawewa': 'Sooriyawewa',
    'Sewanagala': 'Sevanagala',
    'Baththala': 'Buttala',
    'Wellawali': 'Porativu Pattu',
    'damana': 'Damana',
    'M.Nu.P': 'N. Palatha Central',
    'Mathale': 'Matale',
    'Wawunathiw': 'Manmunai West',
    'vavuniya': 'Vavuniya',
    'Thanamalwila': 'Thanamalvila',
    'Alayadivembu': 'Alayadiwembu',
    'Pattipalei': 'Manmunai South-West',
    'Horowpathana': 'Horowpothana',
    'Chankaladi': 'Eravur Pattu',
    'Tamankaduwa': 'Thamankaduwa',
    'Karuwalgaswewa': 'Karuwalagaswewa',
    'Haldhummulla': 'Hildummulla',
    'M.N.P': 'N. Palatha Central',
    'Mulankavil': 'Poonakary',
    'Madavachchiya': 'Medawachchiya',
    'Ambilipitiya': 'Embilipitiya',
    'Manthai west': 'Manthai West',
    'Nintavur': 'Ninthavur',
    'nanattan': 'Nanaddan',
    'Galkiriyagama': 'Palagala',
    'Nedunkanar': 'Vavuniya North',
    'Adampan': 'Manthai West',
    'Nadunkanari': 'Vavuniya North',
    'Navagattegama': 'Nawagattegama',
    'Tirappane': 'Thirappane',
    'Mutur': 'Muttur',
    'Mahakubukkadawala': 'Mahakumbukkadawala',
    'Siripura': 'Dimbulagala',
    'Nagara Ha Kadavatha': 'Trincomalee Town and Gravets',
}

# %%
df['D/S Office'] = df['D/S Office'].replace(replacement_dict)

# %%
df['D/S Office'].unique()
# Out:
# array(['Katharagama', 'Thanamalvila', 'Unknown', 'Thirukkovil',
#        'Ipalogama', 'Pannala', 'Madulla', 'Wellawaya', 'Mahaoya',
#        'Dambulla', 'Addalachchenai', 'Ehetuwewa', 'Hingurakgoda',
#        'Musali', 'Samanthurai', 'Thirappane', 'Hildummulla',
#        'Mannar Town', 'Pothuvil', 'Uhana', 'Maha Vilachchiya',
#        'Kuchchaveli', 'Lahugala', 'Kantalai', 'Wilgamuwa', 'Hambantota',
#        'Dehiattakandiya', 'Manmunai South and Eruvilpattu',
#        'Padiyathalawa', 'Buttala', 'Elahera', 'Horowpothana', 'Seruvila',
#        'Porativu Pattu', 'Mahiyanganaya', 'Dimbulagala', 'Palugaswewa',
#        'Morawewa', 'Damana', 'Welikanda', 'Sooriyawewa', 'Nachchadoowa',
#        'Ambanpola', 'Palagala', 'Rambewa', 'Ampara', 'Nawagattegama',
#        'Medagama', 'Medawachchiya', 'Siyambalanduwa', 'Thissamaharama',
#        'N. Palatha Central', 'Kinniya', 'Galgamuwa', 'Galenbindunuwewa',
#        'Ambalanthota', 'Laggala-Pallegama', 'Kandaketiya', 'Embilipitiya',
# ...

# %%
unique_values_df = df['D/S Office'].unique()
unique_values_gdf = gdf['NAME_2'].unique()

# Check if the unique values in the two columns are the same
if set(unique_values_df) == set(unique_values_gdf):
    print("The unique values in 'D/S Office' and 'NAME_2' are the same.")
else:
    print("The unique values in 'D/S Office' and 'NAME_2' are different.")
# Out:
# The unique values in 'D/S Office' and 'NAME_2' are different.

# %%
unique_values_df = set(df['D/S Office'].unique())
unique_values_gdf = set(gdf['NAME_2'].unique())

# Find the values that are unique to each set
unique_to_df = unique_values_df - unique_values_gdf
unique_to_gdf = unique_values_gdf - unique_values_df

print("Unique values in 'D/S Office' not in 'NAME_2':", unique_to_df)
#print("Unique values in 'NAME_2' not in 'D/S Office':", unique_to_gdf)
# Out:
# Unique values in 'D/S Office' not in 'NAME_2': {'Unknown'}

# %%
df[df['D/S Office']=='Unknown']
# Out:
#         No                 Region      District D/S Office Date of Death  \
# 2        3          North Western  Anuradhapura    Unknown    2010-01-08
# 7        8          North Western      Puttalam    Unknown    2010-01-20
# 30      31          North Western       Unknown    Unknown    2010-03-08
# 32      33          North Western    Monaragala    Unknown    2010-03-12
# 41      42          North Western       Unknown    Unknown    2010-03-21
# 64      65          North Western  Anuradhapura    Unknown    2010-04-27
# 403    404          North Western      Vavuniya    Unknown    2011-08-23
# 430    431          North Western  Anuradhapura    Unknown    2011-10-01
# 440    441          North Western  Anuradhapura    Unknown    2011-10-07
# 555    556            Polonnaruwa   Trincomalee    Unknown    2012-04-09
# 692    693            Polonnaruwa   Polonnaruwa    Unknown    2012-11-06
# 703    704            Polonnaruwa   Polonnaruwa    Unknown    2012-11-16
# ...

# %%
df.loc[(df['District'] == 'Ratnapura') & (df['D/S Office'] == 'Unknown'), 'D/S Office'] = 'Ratnapura'
df.loc[(df['District'] == 'Puttalam') & (df['D/S Office'] == 'Unknown'), 'D/S Office'] = 'Puttalam'
df.loc[(df['District'] == 'Vavuniya') & (df['D/S Office'] == 'Unknown'), 'D/S Office'] = 'Vavuniya'

# %%
df[df['D/S Office']=='Unknown']
# Out:
#         No         Region      District D/S Office Date of Death  \
# 2        3  North Western  Anuradhapura    Unknown    2010-01-08
# 30      31  North Western       Unknown    Unknown    2010-03-08
# 32      33  North Western    Monaragala    Unknown    2010-03-12
# 41      42  North Western       Unknown    Unknown    2010-03-21
# 64      65  North Western  Anuradhapura    Unknown    2010-04-27
# 430    431  North Western  Anuradhapura    Unknown    2011-10-01
# 440    441  North Western  Anuradhapura    Unknown    2011-10-07
# 555    556    Polonnaruwa   Trincomalee    Unknown    2012-04-09
# 692    693    Polonnaruwa   Polonnaruwa    Unknown    2012-11-06
# 703    704    Polonnaruwa   Polonnaruwa    Unknown    2012-11-16
# 710    711    Polonnaruwa   Polonnaruwa    Unknown    2012-11-28
# 1102  1103    Kilinochchi    Mullaitivu    Unknown    2014-08-31
# 1105  1106            Uva    Monaragala    Unknown    2014-09-09
# ...

# %%
gdf.rename(columns={'NAME_2': 'D/S Office'}, inplace=True)

# %%
elephant_deaths_by_ds = df['D/S Office'].value_counts().reset_index()
elephant_deaths_by_ds.columns = ['D/S Office', 'ElephantDeaths']

# %%
elephant_deaths_by_ds
# Out:
#            D/S Office  ElephantDeaths
# 0         Dimbulagala              77
# 1        Thanamalvila              63
# 2        Horowpothana              60
# 3        Hingurakgoda              60
# 4           Welikanda              57
# ..                ...             ...
# 120  Puthukudiyiruppu               1
# 121     Maritimepattu               1
# 122     Hanguranketha               1
# 123         Anamaduwa               1
# 124    Rideemaliyadda               1
#
# [125 rows x 2 columns]

# %%
elephant_deaths_by_ds.head(20)
# Out:
#          D/S Office  ElephantDeaths
# 0       Dimbulagala              77
# 1      Thanamalvila              63
# 2      Horowpothana              60
# 3      Hingurakgoda              60
# 4         Welikanda              57
# 5          Morawewa              47
# 6          Kantalai              46
# 7           Mahaoya              44
# 8        Hambantota              44
# 9      Embilipitiya              41
# 10         Lahugala              40
# 11    Mahiyanganaya              35
# 12  Karuwalagaswewa              33
# 13  Gomarankadawala              33
# 14        Wellawaya              31
# 15   Thissamaharama              29
# 16            Uhana              29
# 17         Kekirawa              28
# 18     Medirigiriya              28
# 19      Thirukkovil              28

# %%
merged_data = gdf.merge(elephant_deaths_by_ds, on='D/S Office', how='left')

# %%
merged_data.head(5)
# Out:
#    ID_0  ISO     NAME_0  ID_1  NAME_1  ID_2      D/S Office    TYPE_2  \
# 0   217  LKA  Sri Lanka     1  Ampara     1  Addalachchenai  Division
# 1   217  LKA  Sri Lanka     1  Ampara     2    Akkaraipattu  Division
# 2   217  LKA  Sri Lanka     1  Ampara     3    Alayadiwembu  Division
# 3   217  LKA  Sri Lanka     1  Ampara     4          Ampara  Division
# 4   217  LKA  Sri Lanka     1  Ampara     5          Damana  Division
#
#   ENGTYPE_2  NL_NAME_2 VARNAME_2  \
# 0  Division        NaN       NaN
# 1  Division        NaN       NaN
# 2  Division        NaN       NaN
# 3  Division        NaN       NaN
# 4  Division        NaN       NaN
#
#                                             geometry  ElephantDeaths
# 0  POLYGON ((81.86070 7.24601, 81.86042 7.24597, ...            10.0
# 1  MULTIPOLYGON (((81.85958 7.24614, 81.85958 7.2...             1.0
# 2  POLYGON ((81.86153 7.21050, 81.86153 7.21014, ...             3.0
# ...

# %%
merged_data['ElephantDeaths'].fillna(0, inplace=True)

# %%
# Set up the plot
fig, ax = plt.subplots(1, 1, figsize=(24, 20))

# Plot the map 
merged_data.plot(column='ElephantDeaths', cmap='Reds', linewidth=0.8, edgecolor='0.8', legend=True, ax=ax)

# Add district names as labels with an offset above the district boundary
#merged_data[merged_data['ElephantDeaths'] > 0].apply(lambda x: ax.annotate(text=x['D/S Office'], xy=x.geometry.centroid.coords[0], ha='center', va='bottom',fontsize=10), axis=1)

# Add the number of deaths as labels with an offset below the district boundary, excluding zeros
merged_data[merged_data['ElephantDeaths'] > 0].apply(lambda x: ax.annotate(text=str(int(x['ElephantDeaths'])), xy=x.geometry.centroid.coords[0], ha='center', va='top'), axis=1)

# Add a title
plt.title('Elephant Deaths by D/S Office in Sri Lanka 2010-2018')

# Show the map
plt.show()

# %%
# Create a mapping of causes to common categories
cause_mapping = {
    'Unknown': 'Unknown',
    'Gunshot': 'Intentional',
    'Hakkapatas': 'Intentional',
    'Electrocuted': 'Unintentional',
    'Natural': 'Natural',
    'Accident': 'Unintentional',
    'Train Accident': 'Unintentional',
    'Poisned': 'Intentional',
    'Other': 'Other',
    'Injured': 'Natural',
    'Body destroyed': 'Unknown',
    'Disease': 'Natural',
    'Fallen into well': 'Natural',
    'Septicemia': 'Natural',
    'Land mine': 'Intentional',
    'Attack by an elephant': 'Natural',
    'Flood': 'Natural',
    'Drowned': 'Natural',
    'Eaten polythene': 'Unintentional',
    'Lightning': 'Natural',
    'Broken the Spinal': 'Natural',
    'At born': 'Natural',
    'Falling of a mountain': 'Natural',
    'Garbage consumption': 'Unintentional',
    'Liver floot': 'Natural',
    'Severe hemorrhage': 'Natural',
    'Nivukeniya': 'Natural',
    'Drought': 'Natural'
}

# Load the dataset
# (Assuming you already have this loaded)

# Apply the mapping to create a new 'Common Cause' column
df['Main_Cause'] = df['Cause of Death'].map(cause_mapping)

# %%
df.head()
# Out:
#    No         Region      District    D/S Office Date of Death  \
# 0   1       Southern    Monaragala   Katharagama    2010-01-01
# 1   2       Southern    Monaragala  Thanamalvila    2010-01-07
# 2   3  North Western  Anuradhapura       Unknown    2010-01-08
# 3   4        Eastern        Ampara   Thirukkovil    2010-01-12
# 4   5  North Western    Kurunegala     Ipalogama    2010-01-15
#
#    Cause of Death     Sex    Age          Age Category     Main_Cause
# 0  Body destroyed    Male  50-55  Subadults and adults        Unknown
# 1         Unknown    Male     20  Subadults and adults        Unknown
# 2    Electrocuted    Male  30-35  Subadults and adults  Unintentional
# 3         Gunshot  Female  15-20  Subadults and adults    Intentional
# 4        Accident    Male      5              Juvenile  Unintentional

# %%
output_file_path = r'..\..\data\Cleaned_data\Updated_ele_deaths.csv'

df.to_csv(output_file_path, index=False)
