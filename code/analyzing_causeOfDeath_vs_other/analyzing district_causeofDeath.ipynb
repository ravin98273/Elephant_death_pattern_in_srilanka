# %%
import geopandas as gpd
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from ipywidgets import interact, widgets
from IPython.display import display
from ipywidgets import interact, widgets
from IPython.display import display, clear_output

# %%
df_ele=pd.read_csv(r'..\..\data\Cleaned_data\cancat_Update_DS.csv')

# %%
df_ele.head()
# Out:
#    No         Region      District    D/S Office Date of Death  \
# 0   1       Southern    Monaragala   Katharagama    2010-01-01
# 1   2       Southern    Monaragala  Thanamalvila    2010-01-07
# 2   3  North Western  Anuradhapura       Unknown    2010-01-08
# 3   4        Eastern        Ampara   Thirukkovil    2010-01-12
# 4   5  North Western    Kurunegala     Ipalogama    2010-01-15
#
#    Cause of Death     Sex    Age          Age Category     Main_Cause
# 0  Body destroyed    Male  50-55  Subadults and adults        Unknown
# 1         Unknown    Male     20  Subadults and adults        Unknown
# 2    Electrocuted    Male  30-35  Subadults and adults  Unintentional
# 3         Gunshot  Female  15-20  Subadults and adults    Intentional
# 4        Accident    Male      5              Juvenile  Unintentional

# %%
df=df_ele[df_ele["Cause of Death"]!='Unknown']

# %% [markdown]
# Group Data by Region and Population:
# + Group the data by the 'Region' and 'District' columns to analyze variations in causes of death within different regions and populations:

# %%
grouped = df.groupby(['District'])

# %% [markdown]
# Count Causes of Death:
# + Count the occurrences of each cause of death within each region and population:

# %%
df['Cause of Death'].value_counts()
# Out:
# Cause of Death
# Gunshot                  403
# Hakkapatas               299
# Electrocuted             169
# Natural                   87
# Accident                  77
# Train Accident            76
# Poisned                   71
# Other                     67
# Injured                   45
# Body destroyed            40
# Disease                   21
# Fallen into well          15
# Septicemia                13
# Land mine                 10
# Attack by an elephant     10
# Flood                      6
# Drowned                    6
# Eaten polythene            6
# Lightning                  4
# Broken the Spinal          3
# At born                    3
# Falling of a mountain      2
# Garbage consumption        1
# Liver floot                1
# Severe hemorrhage          1
# Nivukeniya                 1
# Drought                    1
# Name: count, dtype: int64

# %%
cause_counts = grouped['Cause of Death'].value_counts().unstack(fill_value=0)

# %%
cause_counts
# Out:
# Cause of Death  Accident  At born  Attack by an elephant  Body destroyed  \
# District
# Ampara                 5        0                      1               8
# Anuradhapura          15        0                      3               2
# Badulla                2        0                      0               4
# Batticaloa             1        0                      0               0
# Hambantota             4        1                      1               5
# Kandy                  1        0                      0               0
# Kilinochchi            0        0                      0               0
# Kurunegala             9        0                      1               2
# Mannar                 1        0                      0               1
# Matale                 5        0                      0               3
# Monaragala             4        0                      1               3
# Mullaitivu             1        0                      0               0
# Nuwara Eliya           0        0                      0               0
# Polonnaruwa           14        0                      1               4
# Puttalam               9        2                      2               1
# Ratnapura              1        0                      0               2
# Trincomalee            3        0                      0               5
# Unknown                1        0                      0               0
# Vavuniya               1        0                      0               0
#
# Cause of Death  Broken the Spinal  Disease  Drought  Drowned  Eaten polythene  \
# District
# Ampara                          0        7        0        1                2
# Anuradhapura                    0        0        0        0                0
# Badulla                         0        0        0        0                0
# Batticaloa                      0        0        0        0                1
# Hambantota                      0        1        0        0                0
# Kandy                           0        0        0        0                0
# Kilinochchi                     0        0        0        0                0
# Kurunegala                      1        0        1        0                0
# Mannar                          0        2        0        0                0
# Matale                          0        0        0        0                0
# Monaragala                      0        5        0        0                0
# Mullaitivu                      0        0        0        0                0
# Nuwara Eliya                    0        0        0        0                0
# Polonnaruwa                     2        3        0        2                3
# Puttalam                        0        2        0        0                0
# Ratnapura                       0        1        0        1                0
# Trincomalee                     0        0        0        1                0
# Unknown                         0        0        0        0                0
# Vavuniya                        0        0        0        1                0
#
# Cause of Death  Electrocuted  ...  Land mine  Lightning  Liver floot  Natural  \
# District                      ...
# Ampara                    18  ...          1          0            0        8
# Anuradhapura              38  ...          1          4            0        4
# Badulla                    5  ...          0          0            0        2
# Batticaloa                18  ...          0          0            0        2
# Hambantota                20  ...          0          0            1        6
# Kandy                      3  ...          0          0            0        0
# Kilinochchi                1  ...          0          0            0        0
# Kurunegala                14  ...          1          0            0        2
# Mannar                     1  ...          2          0            0        0
# Matale                     5  ...          0          0            0        2
# Monaragala                10  ...          0          0            0       13
# Mullaitivu                 0  ...          1          0            0        0
# Nuwara Eliya               0  ...          0          0            0        4
# Polonnaruwa               15  ...          1          0            0        7
# Puttalam                   6  ...          0          0            0        3
# Ratnapura                  1  ...          0          0            0       31
# Trincomalee                7  ...          1          0            0        3
# Unknown                    0  ...          0          0            0        0
# Vavuniya                   7  ...          2          0            0        0
#
# Cause of Death  Nivukeniya  Other  Poisned  Septicemia  Severe hemorrhage  \
# District
# Ampara                   0      8       11          10                  0
# Anuradhapura             1      7       16           0                  0
# Badulla                  0      1        0           0                  0
# Batticaloa               0      2        4           1                  0
# Hambantota               0      7        2           0                  0
# Kandy                    0      0        1           0                  0
# Kilinochchi              0      0        0           0                  0
# Kurunegala               0      2       13           0                  0
# Mannar                   0      1        0           0                  0
# Matale                   0      2        1           0                  0
# Monaragala               0      7        5           2                  1
# Mullaitivu               0      0        0           0                  0
# Nuwara Eliya             0      0        0           0                  0
# Polonnaruwa              0     16        6           0                  0
# Puttalam                 0      4        3           0                  0
# Ratnapura                0      1        0           0                  0
# Trincomalee              0      9        6           0                  0
# Unknown                  0      0        1           0                  0
# Vavuniya                 0      0        2           0                  0
#
# Cause of Death  Train Accident
# District
# Ampara                       0
# Anuradhapura                11
# Badulla                      0
# Batticaloa                   3
# Hambantota                   0
# Kandy                        0
# Kilinochchi                  1
# Kurunegala                  10
# Mannar                       0
# Matale                       0
# Monaragala                   0
# Mullaitivu                   3
# Nuwara Eliya                 0
# Polonnaruwa                 34
# Puttalam                     2
# Ratnapura                    0
# Trincomalee                  1
# Unknown                      0
# Vavuniya                    11
#
# [19 rows x 27 columns]

# %%
for district, data in cause_counts.iterrows():
    total = data.sum()
    percentages = (data / total) * 100

    # Filter out bars with value 0
    data = data[data > 0]
    percentages = percentages[data.index]

    if not data.empty:
        plt.figure(figsize=(10, 6))
        ax = data.plot(kind='bar', title=f'Causes of Death in {district}')
        
        plt.xlabel('Cause of Death')
        plt.ylabel('Count')
        plt.xticks(rotation=90)

        # Annotate each bar with its percentage
        for i, value in enumerate(data):
            percentage = percentages.iloc[i]
            ax.text(i, value-0.5, f'{percentage:.2f}%', ha='center', va='bottom', rotation=45)

        plt.show()

# %% [markdown]
# Identify Common Causes of Death:

# %%
common_causes = cause_counts.apply(lambda x: x.idxmax(), axis=1)

# %%
common_causes=pd.DataFrame(common_causes)

# %%
common_causes.reset_index(inplace=True)

# %%
common_causes = common_causes.rename(columns={0: 'CommonCause'})

# %%
common_causes
# Out:
#         District   CommonCause
# 0         Ampara       Gunshot
# 1   Anuradhapura    Hakkapatas
# 2        Badulla       Gunshot
# 3     Batticaloa       Gunshot
# 4     Hambantota  Electrocuted
# 5          Kandy  Electrocuted
# 6    Kilinochchi  Electrocuted
# 7     Kurunegala       Gunshot
# 8         Mannar       Gunshot
# 9         Matale       Gunshot
# 10    Monaragala       Gunshot
# 11    Mullaitivu    Hakkapatas
# 12  Nuwara Eliya       Natural
# 13   Polonnaruwa       Gunshot
# 14      Puttalam       Gunshot
# 15     Ratnapura       Natural
# 16   Trincomalee    Hakkapatas
# 17       Unknown      Accident
# 18      Vavuniya    Hakkapatas

# %%
# Load the district shapefile
districts = gpd.read_file(r'..\..\data\Map_file\District_geo.json')

# %%
districts.head()
# Out:
#         ADM2_EN            ADM2_SI                ADM2_TA ADM2_PCODE ADM2_REF  \
# 0     [unknown]          [unknown]  [unknoபுத்தளம் மாவட்ட       LK60
# 1        Ampara  අම්පාර දිස්ත්‍රික       அம்பாறை மாவட்டம்       LK52
# 2  Anuradhapura  අනුරාධපුර දිස්ත්‍      அனுராதபுரம் மாவட்       LK71
# 3       Badulla  බදුල්ල දිස්ත්‍රික         பதுளை மாவட்டம்       LK81
# 4    Batticaloa  මඩකලපුව දිස්ත්‍රි      மட்டக்களப்பு மாவட       LK51
#
#   ADM2ALT1EN ADM2ALT2EN ADM2ALT1SI ADM2ALT2SI ADM2ALT1TA  ...    ADM0_EN  \
# 0                                                         ...  Sri Lanka
# 1                                                         ...  Sri Lanka
# 2                                                         ...  Sri Lanka
# 3                                                         ...  Sri Lanka
# 4                                                         ...  Sri Lanka
#
#       ADM0_SI ADM0_TA ADM0_PCODE Shape_Leng Shape_Area  \
# 0  ශ්‍රී ලංකා  இலங்கை         LK   0.286741   0.002137
# 1  ශ්‍රී ලංකා  இலங்கை         LK   5.397133   0.366562
# 2  ශ්‍රී ලංකා  இலங்கை         LK   4.539544   0.592676
# 3  ශ්‍රී ලංකා  இலங்கை         LK   3.940419   0.235108
# 4  ශ්‍රී ලංකා  இலங்கை         LK   6.468261   0.203262
#
#                        date                   validOn  \
# 0 2019-03-04 00:00:00+00:00 2020-03-05 00:00:00+00:00
# 1 2019-03-04 00:00:00+00:00 2020-03-05 00:00:00+00:00
# 2 2019-03-04 00:00:00+00:00 2020-03-05 00:00:00+00:00
# 3 2019-03-04 00:00:00+00:00 2020-03-05 00:00:00+00:00
# 4 2019-03-04 00:00:00+00:00 2020-03-05 00:00:00+00:00
#
#                     validTo                                           geometry
# 0 1899-11-30 00:00:00+00:00  POLYGON ((79.82493 7.78566, 79.82341 7.78844, ...
# 1 1899-11-30 00:00:00+00:00  POLYGON ((81.75144 7.45764, 81.74739 7.45469, ...
# 2 1899-11-30 00:00:00+00:00  POLYGON ((80.93922 8.34202, 80.93707 8.34614, ...
# 3 1899-11-30 00:00:00+00:00  POLYGON ((81.26884 7.27764, 81.26596 7.28468, ...
# 4 1899-11-30 00:00:00+00:00  MULTIPOLYGON (((81.72618 7.63616, 81.72664 7.6...
#
# [5 rows x 25 columns]

# %%
# Rename the district column to 'District'
districts.rename(columns={'ADM2_EN': 'District'}, inplace=True)

# %%
# Remove the 'unknown' district
districts = districts[districts['District'] != '[unknown]']

# %%
# Merge the data with district boundaries data
merged_data_all = districts.merge(common_causes, on='District', how='left')

# %%
merged_data_all.head()
# Out:
#        District            ADM2_SI            ADM2_TA ADM2_PCODE ADM2_REF  \
# 0        Ampara  අම්පාර දිස්ත්‍රික   அம்பாறை மாவட்டம்       LK52
# 1  Anuradhapura  අනුරාධපුර දිස්ත්‍  அனுராதபுரம் மாவட்       LK71
# 2       Badulla  බදුල්ල දිස්ත්‍රික     பதுளை மாவட்டம்       LK81
# 3    Batticaloa  මඩකලපුව දිස්ත්‍රි  மட்டக்களப்பு மாவட       LK51
# 4       Colombo  කොළඹ දිස්ත්‍රික්ක  கொழும்பு மாவட்டம்       LK11
#
#   ADM2ALT1EN ADM2ALT2EN ADM2ALT1SI ADM2ALT2SI ADM2ALT1TA  ...     ADM0_SI  \
# 0                                                         ...  ශ්‍රී ලංකා
# 1                                                         ...  ශ්‍රී ලංකා
# 2                                                         ...  ශ්‍රී ලංකා
# 3                                                         ...  ශ්‍රී ලංකා
# 4                                                         ...  ශ්‍රී ලංකා
#
#   ADM0_TA ADM0_PCODE Shape_Leng Shape_Area                      date  \
# 0  இலங்கை         LK   5.397133   0.366562 2019-03-04 00:00:00+00:00
# 1  இலங்கை         LK   4.539544   0.592676 2019-03-04 00:00:00+00:00
# 2  இலங்கை         LK   3.940419   0.235108 2019-03-04 00:00:00+00:00
# 3  இலங்கை         LK   6.468261   0.203262 2019-03-04 00:00:00+00:00
# 4  இலங்கை         LK   1.887285   0.056092 2019-03-04 00:00:00+00:00
#
#                     validOn                   validTo  \
# 0 2020-03-05 00:00:00+00:00 1899-11-30 00:00:00+00:00
# 1 2020-03-05 00:00:00+00:00 1899-11-30 00:00:00+00:00
# 2 2020-03-05 00:00:00+00:00 1899-11-30 00:00:00+00:00
# 3 2020-03-05 00:00:00+00:00 1899-11-30 00:00:00+00:00
# 4 2020-03-05 00:00:00+00:00 1899-11-30 00:00:00+00:00
#
#                                             geometry  CommonCause
# 0  POLYGON ((81.75144 7.45764, 81.74739 7.45469, ...      Gunshot
# 1  POLYGON ((80.93922 8.34202, 80.93707 8.34614, ...   Hakkapatas
# 2  POLYGON ((81.26884 7.27764, 81.26596 7.28468, ...      Gunshot
# 3  MULTIPOLYGON (((81.72618 7.63616, 81.72664 7.6...      Gunshot
# 4  POLYGON ((80.17721 6.97725, 80.16917 6.97930, ...          NaN
#
# [5 rows x 26 columns]

# %%
merged_data_all['CommonCause'].fillna('No Deaths', inplace=True)

# %%
# Plot the map
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
merged_data_all.boundary.plot(ax=ax, linewidth=.5, color='black')
merged_data_all.plot(column='CommonCause', cmap='jet_r', linewidth=0.8, ax=ax, legend=True)
merged_data_all.apply(lambda x: ax.annotate(text=x['District'], xy=x.geometry.centroid.coords[0], ha='center', va='bottom'), axis=1)
ax.set_title('Common Causes of Elephant Death by District')
plt.show()

# %% [markdown]
# For year wise

# %%
@interact(year=widgets.IntSlider(value=2010, min=2010, max=2017, step=1, description='Year'))
def plot_map(year):
    clear_output(wait=True)
    # Load and process your data for the selected year
    df = pd.read_csv(f'D:/UOP/4th year/Research/EDA/Data/{year}_clean.csv')
    df = df[df["Cause of Death"] != 'Unknown']
    grouped = df.groupby(['District'])
    cause_counts = grouped['Cause of Death'].value_counts().unstack(fill_value=0)
    common_causes = cause_counts.apply(lambda x: x.idxmax(), axis=1)
    common_causes = common_causes.rename('CommonCause')
    
    # Get the number of deaths for each cause
    cause_deaths = cause_counts.max(axis=1)
    cause_deaths = cause_deaths.rename('NumDeaths')
    
    # Merge data with district boundaries data
    merged_data = districts.merge(common_causes, on='District', how='left')
    merged_data = merged_data.merge(cause_deaths, on='District', how='left')
    merged_data['CommonCause'].fillna('No Deaths', inplace=True)
    merged_data['NumDeaths'].fillna(0, inplace=True)

    # Create a Plotly map for the selected year
    fig, ax = plt.subplots(1, 1, figsize=(15, 10))
    merged_data_all.boundary.plot(ax=ax, linewidth=.5, color='black')
    merged_data.plot(column='CommonCause', cmap='Accent', linewidth=0.8, ax=ax, legend=True)
    
    
    merged_data.apply(lambda x: ax.annotate(text=str(int(x['NumDeaths'])), xy=x.geometry.centroid.coords[0], ha='center', va='top'), axis=1)
    merged_data.apply(lambda x: ax.annotate(text=x['District'], xy=x.geometry.centroid.coords[0], ha='center', va='bottom'), axis=1)
        
    plt.title(f'Common Causes of Elephant Death by District ({year})')
    plt.show()
# Out:
# interactive(children=(IntSlider(value=2010, description='Year', max=2017, min=2010), Output()), _dom_classes=(…
